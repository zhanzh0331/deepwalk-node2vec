# %% [markdown]
# # DeepWalk实战-维基百科词条图嵌入可视化

# %% [markdown]
# ## 安装工具包

# %%
# !pip install networkx gensim pandas numpy tqdm scikit-learn matplotlib

# %% [markdown]
# ## 导入工具包

# %%
import networkx as nx # 图数据挖掘

# 数据分析
import pandas as pd
import numpy as np

import random # 随机数
from tqdm import tqdm # 进度条

# 数据可视化
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签  
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号

# %%
df = pd.read_csv("bilibili_tag.csv", sep = "\t")

# %%
df.head()
# Out:
#     A      B
# 0  嘻哈  音乐分享官
# 1  嘻哈    GAI
# 2  嘻哈     音乐
# 3  嘻哈   音乐综合
# 4  嘻哈   经典现场

# %%
df.shape
# Out:
# (2021, 2)

# %% [markdown]
# ## 构建无向图

# %%
G = nx.from_pandas_edgelist(df, df.columns[0], df.columns[1], create_using=nx.Graph())

# %%
# 节点个数
len(G)
# Out:
# 559

# %% [markdown]
# ## 可视化

# %%
# 可视化
plt.figure(figsize=(15,14))
nx.draw(G)
plt.show()

# %% [markdown]
# ## 生成随机游走节点序列的函数

# %%
def get_randomwalk(node, path_length):
    '''
    输入起始节点和路径长度，生成随机游走节点序列
    '''
    
    random_walk = [node]
    
    for i in range(path_length-1):
        # 汇总邻接节点
        temp = list(G.neighbors(node))
        temp = list(set(temp) - set(random_walk))    
        if len(temp) == 0:
            break
        # 从邻接节点中随机选择下一个节点
        random_node = random.choice(temp)
        random_walk.append(random_node)
        node = random_node
        
    return random_walk

# %%
all_nodes = list(G.nodes())

# %%
all_nodes
# Out:
# ['嘻哈',
#  '音乐分享官',
#  'GAI',
#  '音乐',
#  '音乐综合',
#  '经典现场',
#  'VAVA',
#  '中文说唱',
#  '小青龙',
#  '艾福杰尼',
#  '黄旭',
#  'Jony J',
#  '中国有嘻哈',
#  '音乐分享官5.0',
#  '极乐净土',
#  '乐评盘点',
#  '二次元',
#  '动漫音乐',
#  'ACG音乐',
#  'One last kiss',
#  '音乐分享官7.0',
#  '美依礼芽',
#  '群青',
#  'B站神曲',
#  '萌娃',
#  '运动',
#  '音乐推荐',
#  '歌曲',
#  '动物',
#  '听歌',
#  '拍摄',
#  '高能娱评官',
#  '必剪创作',
#  '娱乐',
#  '娱乐杂谈',
#  '生活',
#  '萌',
#  '可爱',
#  '治愈系',
#  '网红',
#  '瑶一瑶',
#  '热播综艺',
#  '星动安利大作战·春日篇',
#  '经典',
#  '穿越时空的思念',
#  '音乐分享官4.0',
#  '幻昼',
#  '伤感纯音乐',
#  '告白之夜',
#  '纯音乐',
#  '轻音乐',
#  '高音质',
#  'BGM',
#  '雨的印记',
#  '我的世界',
#  '音游',
#  '演奏',
#  '单机游戏',
#  '音乐游戏',
#  'MC',
#  '别人的世界',
#  '红石音乐',
#  '耍把戏',
#  '音乐教学',
#  '视频',
#  '视唱练耳',
#  '听音',
#  '艺考',
#  '课堂',
#  '系列',
#  '钢琴',
#  '流行音乐',
#  '自学教程',
#  '电钢琴入门',
#  '音乐制作',
#  '伴奏',
#  '即兴伴奏',
#  '学习资料',
#  '钢琴教学',
#  '学音乐',
#  '钢琴曲',
#  '暑期爆肝挑战',
#  '钢琴演奏',
#  'Bi.Bi',
#  '独奏',
#  '夏日音乐祭',
#  '音乐安利大赏',
#  '翻唱',
#  'KPOP人集合企划',
#  '欧美音乐',
#  '英文歌曲',
#  '英文',
#  '洗脑',
#  '音乐安利大赏2.0',
#  'The Backrooms',
#  'backrooms',
#  '后室',
#  'Level!',
#  'Level ！',
#  '音乐分享官6.0',
#  '校园',
#  '太好听了',
#  '学生',
#  '宅舞',
#  '舞蹈',
#  'GARNiDELiA',
#  'Miume・MARiA・217',
#  '217',
#  'MARiA',
#  'miume',
#  'みうめ',
#  '一起看姐姐72面',
#  '综艺',
#  '乘风2023',
#  '星动安利大作战·初夏篇',
#  '龚琳娜',
#  '小美',
#  '极乐净土三人组金曲心动挑战',
#  '同学',
#  '尬舞',
#  '4K',
#  '音乐现场',
#  'LIVE',
#  '演唱会',
#  '无损',
#  'GARNIDELIA',
#  '爷青回',
#  'BML',
#  'メイリア',
#  '日语现场',
#  '讴歌烂漫',
#  '水桥舞',
#  '再跳一遍《极乐净土》回忆杀',
#  '现场',
#  '燃向',
#  'live',
#  '原神',
#  '动画',
#  'MMD·3D',
#  '2D渲染',
#  '雷电将军',
#  'MMD',
#  'MMD.3D',
#  '原神MMD',
#  '流浪者',
#  '散兵',
#  '蹦迪',
#  '咬人猫',
#  '镇站之宝',
#  '约尔',
#  '约尔太太',
#  '间谍过家家',
#  '游戏',
#  '停云',
#  '崩坏:星穹铁道',
#  '音乐研究所',
#  '盘点排行',
#  '神曲',
#  '国产',
#  '盘点',
#  '宝藏歌曲',
#  '音乐玩家招募令',
#  '万物研究所',
#  '人工智能',
#  '互联网',
#  '知识',
#  '科学科普',
#  '华语音乐',
#  '学习',
#  '研究',
#  '数据',
#  '傅里叶变换',
#  '万物研究所·第七期',
#  '深度学习',
#  'billboard',
#  'adele',
#  'taylorswift',
#  'mariah',
#  '撞弦',
#  '热门歌曲',
#  '抄袭',
#  '网络歌曲',
#  '反抄袭',
#  '精选歌单',
#  '音乐榜单资讯',
#  '歌单',
#  '音乐选集',
#  '2022年最火歌曲',
#  '吐槽',
#  '音乐分享官3.0',
#  '营销号',
#  '音乐盘点',
#  '点评',
#  '乐评',
#  '音乐观察局',
#  '霉霉',
#  '欧美',
#  '打雷',
#  '碧梨',
#  '知识分享官',
#  '民谣',
#  '摇滚',
#  '电音',
#  '说唱',
#  '历史',
#  '人文',
#  '心理学',
#  '社科·法律·心理',
#  '男生',
#  '大学',
#  '女生',
#  '记忆力',
#  '社会',
#  '思维',
#  '自信',
#  '2023年',
#  'A神',
#  '梦龙乐队',
#  'RAP',
#  '中国说唱巅峰对决',
#  '2022',
#  '百大',
#  'Rapper',
#  '年度好音乐大赏',
#  '杨丞琳',
#  '毕业季',
#  'MV',
#  '中国',
#  '青春',
#  '毕业',
#  '齐秦',
#  '资讯',
#  '新世代音乐人计划女生季',
#  '韩红',
#  '汪峰',
#  '华晨宇',
#  '原创歌曲',
#  '原创音乐',
#  '歌手',
#  '作曲',
#  'Vicky宣宣',
#  '英文原创',
#  '文艺复兴',
#  '舞蹈翻跳',
#  '张国荣逝世20周年纪念',
#  '张国荣',
#  '官方MV',
#  '纪念',
#  '20周年',
#  '干杯音乐节',
#  '刘彰',
#  '音乐节',
#  '干杯',
#  '小精灵',
#  '翠花不太脆',
#  '翠花',
#  'Bo Peep',
#  '政在联动中',
#  '犯罪',
#  '帮信罪',
#  '银行卡',
#  '以爱之名',
#  '电话卡',
#  '工具人',
#  '两卡',
#  '离别',
#  '合唱团',
#  '感动',
#  '生机勃勃的春天！',
#  '经典老歌',
#  '音乐合集',
#  '##全能音乐挑战赛##',
#  '流行歌曲',
#  '车载音乐',
#  '打卡挑战',
#  '欧美流行',
#  '歌曲合集',
#  '欧美流行音乐',
#  '经典英文歌',
#  '超好听英文歌曲',
#  '英文歌合集',
#  '音乐素人投稿季',
#  '看一遍就爱上的日语现场',
#  '开口跪',
#  '动漫歌曲',
#  '粉丝音乐安利大赛2.0',
#  '综合',
#  '必剪十一大作战',
#  '动漫壁纸',
#  'P站',
#  '九月打卡挑战W4',
#  '手绘',
#  '绘画',
#  '抑郁症',
#  '画渣',
#  '铅笔画',
#  '发病',
#  'AMV',
#  'MAD',
#  'MAD·AMV',
#  'MAD.AMV',
#  '论BGM的重要性',
#  '治愈向',
#  '催泪',
#  '综漫',
#  '南条爱乃',
#  '御坂美琴',
#  '某科学的超电磁炮',
#  '弹幕之神第一季冠军',
#  '见证弹幕的力量',
#  '弹幕狂欢',
#  '炮姐',
#  '高级弹幕',
#  '暗猫',
#  '动画短片群星计划',
#  '动漫',
#  '治愈',
#  '多素材',
#  '视觉盛宴',
#  '动画短片群星计划 第七期',
#  '科幻',
#  '短片·手书·配音',
#  '惊悚',
#  '原创动画',
#  '外星人',
#  '石器时代',
#  '人类学',
#  '编剧',
#  '自制动画',
#  '美图',
#  '壁纸',
#  '我的原神新春会',
#  '时尚',
#  '仿妆cos',
#  '原神UP主激励计划',
#  '妹妹',
#  '八重神子',
#  'Cosplay',
#  '配音',
#  '搞笑',
#  '清醒',
#  '沙雕',
#  '声优',
#  '野生技能协会',
#  '伪音',
#  '配音演员',
#  '伪音教程',
#  '播音',
#  '配音教程',
#  '配音素材',
#  '播音主持',
#  '浪姐教你跳极乐净土',
#  '日本',
#  '粉丝创作',
#  '萌妹子',
#  '偶像',
#  'maria',
#  'MARiA浪姐4跳极乐净土',
#  '人力VOCALOID',
#  '鬼畜',
#  '全明星',
#  '乘风破浪',
#  '二次元中二小剧场',
#  '中二病',
#  '模仿',
#  '分享',
#  '二刺螈',
#  'B站小剧场·新春放映会',
#  '动画加工厂',
#  '轻音少女',
#  '打破次元壁',
#  '新人向',
#  '次元穿越',
#  '动画嘉年华2022·至燃之夏',
#  'C4D',
#  '技术宅',
#  '渲染',
#  '三维动画',
#  '自制',
#  '原创',
#  '你的名字',
#  '鬼灭之刃',
#  'EVA',
#  '进击的巨人',
#  '动漫神曲',
#  '人气排行',
#  '火影忍者',
#  '动漫纯音乐',
#  '处刑曲',
#  'RADWIMPS',
#  'OST',
#  '新海诚',
#  'YOUTUBE搬运',
#  'bilibili新星计划',
#  '补番推荐',
#  '排行榜',
#  '排行向',
#  '中岛美嘉',
#  '影视音乐',
#  '日系',
#  '战歌',
#  '超燃',
#  '热血',
#  '日语',
#  '日语MV',
#  '主题曲',
#  '日本流行音乐',
#  '二次元动漫',
#  '安利',
#  '日本流行',
#  '日语学习',
#  '校园学习',
#  '五十音',
#  '日语教程',
#  '日语入门',
#  '阿飞老师',
#  '日语教材',
#  '日语方法',
#  '治愈音乐',
#  '天花板',
#  '宝藏',
#  '歌声',
#  '超好听的',
#  '灌篮高手',
#  '新世纪福音战士',
#  '名侦探柯南',
#  'CLAMP30周年',
#  '百变小樱',
#  '数码宝贝',
#  '怀旧',
#  'Aimer',
#  '泽野弘之',
#  '刀剑神域',
#  '入耳即洗脑的神曲',
#  '二次元音乐',
#  '听歌向',
#  'OP',
#  '剪辑',
#  '动画短片',
#  '短片',
#  '童年回忆杀',
#  '家庭',
#  '童年',
#  '3D',
#  '获奖',
#  '成长',
#  '海猫鸣泣之时',
#  '自动彩色弹幕',
#  '完结撒花',
#  '高三狂欢节',
#  '水树奈奈',
#  '死神',
#  '海贼王',
#  '超时空要塞',
#  '守护甜心',
#  '月咏歌呗',
#  '迷宫バタフライ',
#  '单曲',
#  '循环',
#  '好听',
#  '很好听',
#  '最强安利王·新片风向标',
#  '绫波丽',
#  '宇多田光',
#  '明日香',
#  '日本明星',
#  '旅游',
#  '出行',
#  '抗日战争',
#  '南京大屠杀',
#  '点亮繁星计划',
#  '觉醒年代',
#  '七七事变',
#  '国家英雄',
#  '靖国神社',
#  '宇多田ヒカル',
#  '新·福音战士剧场版：终',
#  '薰嗣',
#  '2022新年音乐大作战',
#  '男声翻唱',
#  '唱歌',
#  '男声',
#  '音响',
#  '录音棚',
#  '2023新年音乐大作战',
#  '交响乐',
#  '编曲',
#  'DNA',
#  '用交响乐打开2023',
#  '宝藏音乐',
#  '新年音乐',
#  '一月',
#  '创作灵感',
#  '翻唱挑战赛',
#  'COVER',
#  '日文',
#  'one last kiss',
#  '黄昏',
#  '秋日翻唱挑战赛',
#  '和我一起唱歌吧',
#  '粤语',
#  '回春丹',
#  '港风',
#  '声声不息',
#  'bilibili校园十佳歌手大赛',
#  '演奏挑战赛',
#  'A叔',
#  '演奏会',
#  '演奏挑战赛5.0',
#  '全民演奏挑战赛',
#  '西乐也疯狂',
#  '合奏',
#  'oskarpianist',
#  'Animenzzz',
#  'Vinheteiro',
#  'only my railgun',
#  '剧场版',
#  '教程',
#  '罗马音',
#  '中文谐音',
#  'IN-K/王忻辰',
#  '分享歌曲',
#  '存档2022，开拍2023',
#  '国风音乐',
#  '古风',
#  '古风歌曲',
#  '今日无事勾栏听曲',
#  '古风视频',
#  '冥想',
#  '瑜伽',
#  '助眠',
#  '催眠',
#  '阅读学习',
#  '治愈心灵',
#  '深度睡眠',
#  '放松减压',
#  'HIPHOP',
#  'Tom MacDonald',
#  'DISS',
#  '童年记忆',
#  'Rap',
#  '修复视频小潮人',
#  'hiphop',
#  '夏天',
#  '说唱练习打卡',
#  '合集',
#  '经典曲目',
#  '你的男孩TT',
#  '动感视频',
#  'BATTLE',
#  '真人秀',
#  'FREESTYLE',
#  'Battle',
#  '中字',
#  'NF',
#  '华语MV',
#  'TT',
#  'Tizzy T',
#  '2023UP！新学期！']

# %%
get_randomwalk('嘻哈', 5)
# Out:
# ['嘻哈', '说唱', '乐评盘点', '音乐分享官3.0']

# %% [markdown]
# ## 生成随机游走序列

# %%
gamma = 10 # 每个节点作为起始点生成随机游走序列个数
walk_length = 5 # 随机游走序列最大长度

# %%
random_walks = []

for n in tqdm(all_nodes): # 遍历每个节点
    for i in range(gamma): # 每个节点作为起始点生成gamma个随机游走序列
        random_walks.append(get_randomwalk(n, walk_length))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 559/559 [00:00<00:00, 3361.93it/s]

# %%
# 生成随机游走序列个数
len(random_walks)
# Out:
# 5590

# %%
random_walks[1]
# Out:
# ['嘻哈', '黄旭']

# %% [markdown]
# ## 训练Word2Vec模型

# %%
from gensim.models import Word2Vec # 自然语言处理

# %%
model = Word2Vec(vector_size=32, # Embedding维数
                 window=1, # 窗口宽度
                 sg=1, # Skip-Gram
                 hs=0, # 不加分层softmax
                 negative=10, # 负采样
                 alpha=0.03,  # 初始学习率
                 min_alpha=0.0007, # 最小学习率
                 seed=14 # 随机数种子
                )

# %%
# 用随机游走序列构建词汇表
model.build_vocab(random_walks, progress_per=2)

# %%
# 训练（耗时1分钟左右）
model.train(random_walks, total_examples=model.corpus_count, epochs=50, report_delay=1)
# Out:
# (799173, 1125850)

# %% [markdown]
# ## 分析Word2Vec结果

# %%
# 查看某个节点的Embedding
model.wv.get_vector('音乐').shape
# Out:
# (32,)

# %%
model.wv.get_vector('音乐')
# Out:
# array([-0.08831553, -1.0170926 ,  0.45130756,  1.0278484 ,  0.36094657,
#         0.81942767,  0.22376549, -0.72074884,  0.19653893,  0.7548458 ,
#        -0.26442778,  0.15374433,  0.5234439 ,  0.50742996, -0.7768085 ,
#         0.11659869,  0.48586386, -0.31971058,  0.45690334, -0.7799524 ,
#        -0.704643  ,  0.7534467 , -0.18913977,  0.95032126,  0.14423598,
#        -0.26275513, -0.33016878, -0.25724885,  0.13831377,  0.12723176,
#        -0.8888139 , -1.123616  ], dtype=float32)

# %%
# 找相似词语
model.wv.similar_by_word('音乐')
# Out:
# [('经典英文歌', 0.7705228924751282),
#  ('两卡', 0.7622829079627991),
#  ('官方MV', 0.7399069666862488),
#  ('刘彰', 0.735637903213501),
#  ('歌手', 0.7251874804496765),
#  ('小精灵', 0.7221842408180237),
#  ('犯罪', 0.7184068560600281),
#  ('华晨宇', 0.7149216532707214),
#  ('超好听英文歌曲', 0.7130947113037109),
#  ('毕业季', 0.7120380997657776)]

# %% [markdown]
# ## PCA降维可视化

# %% [markdown]
# ### 可视化全部词条的二维Embedding

# %%
X = model.wv.vectors

# %%
# 将Embedding用PCA降维到2维
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
embed_2d = pca.fit_transform(X)

# %%
embed_2d.shape
# Out:
# (559, 2)

# %%
plt.figure(figsize=(8,8))
plt.scatter(embed_2d[:, 0], embed_2d[:, 1])
plt.show()

# %% [markdown]
# ### 可视化某个词条的二维Embedding

# %%
term = '音乐'

# %%
term_256d = model.wv[term].reshape(1,-1)

# %%
term_256d.shape
# Out:
# (1, 32)

# %%
term_2d = pca.transform(term_256d)

# %%
term_2d
# Out:
# array([[-0.12251976, -0.53701824]], dtype=float32)

# %%
# 查找 嘻哈 节点的相似节点
model.wv.most_similar('嘻哈')
# 也可以用下面函数
# model.wv.similar_by_word('嘻哈')
# Out:
# [('中字', 0.7836428284645081),
#  ('中国有嘻哈', 0.7774758338928223),
#  ('DISS', 0.7771409153938293),
#  ('Jony J', 0.7755478024482727),
#  ('动感视频', 0.7742727994918823),
#  ('Rap', 0.770801305770874),
#  ('说唱练习打卡', 0.7699394822120667),
#  ('华语MV', 0.7685351967811584),
#  ('修复视频小潮人', 0.7634388208389282),
#  ('合集', 0.7633681297302246)]

# %%
# 查看任意两个节点的相似度
model.wv.similarity('嘻哈', '说唱')
# Out:
# 0.5766438

# %%
# 查看任意两个节点的相似度
model.wv.similarity('嘻哈', '日语')
# Out:
# 0.2760287

# %%
plt.figure(figsize=(8,8))
plt.scatter(embed_2d[:,0], embed_2d[:,1])
plt.scatter(term_2d[:,0],term_2d[:,1],c='r',s=200)
plt.show()

# %% [markdown]
# ### 可视化某些词条的二维Embedding

# %%
# 计算PageRank重要度
pagerank = nx.pagerank(G)
# 从高到低排序
node_importance = sorted(pagerank.items(), key=lambda x:x[1], reverse=True)

# %%
# 取最高的前n个节点
n = 50
terms_chosen = []
for each in node_importance[:n]:
    terms_chosen.append(each[0])

# %%
# 手动补充新节点
# terms_chosen.extend(['computer vision','deep learning','convolutional neural network','convolution','natural-language processing','attention (machine learning)','support-vector machine','decision tree','random forest','computational imaging','machine vision','cognitive science','neuroscience','psychophysics','brain','visual cortex','visual neuroscience','cognitive model','finite difference','finite difference time domain','finite difference coefficients','finite difference methods for option pricing','iso 128','iso 10303'])

# %%
terms_chosen
# Out:
# ['音乐分享官',
#  '音乐',
#  '二次元',
#  '乐评盘点',
#  '动漫音乐',
#  '嘻哈',
#  'One last kiss',
#  '极乐净土',
#  'ACG音乐',
#  '音乐研究所',
#  '动画',
#  '配音',
#  'AMV',
#  '日本',
#  '动画短片群星计划',
#  '2023新年音乐大作战',
#  '知识分享官',
#  '萌娃',
#  '日语',
#  '演奏挑战赛',
#  '必剪创作',
#  '政在联动中',
#  '钢琴',
#  '翻唱挑战赛',
#  '动画加工厂',
#  '浪姐教你跳极乐净土',
#  '新世纪福音战士',
#  '音乐综合',
#  '翻唱',
#  'BML',
#  '看一遍就爱上的日语现场',
#  '二次元中二小剧场',
#  '音乐安利大赏',
#  '你的名字',
#  '新世代音乐人计划女生季',
#  '一起看姐姐72面',
#  '音乐现场',
#  '中岛美嘉',
#  'LIVE',
#  '再跳一遍《极乐净土》回忆杀',
#  '水树奈奈',
#  '干杯音乐节',
#  '美依礼芽',
#  '张国荣逝世20周年纪念',
#  '极乐净土三人组金曲心动挑战',
#  '娱乐',
#  '生活',
#  '流行音乐',
#  '演奏',
#  '音乐分享官5.0']

# %%
# 输入词条，输出词典中的索引号
term2index = model.wv.key_to_index

# %%
# index2term = model.wv.index_to_key
# term_index = np.array(term2index.values())

# %%
# 可视化全部词条和关键词条的二维Embedding
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:,0], embed_2d[:,1])

for item in terms_chosen:
    idx = term2index[item]
    plt.scatter(embed_2d[idx,0], embed_2d[idx,1],c='r',s=50)
    plt.annotate(item, xy=(embed_2d[idx,0], embed_2d[idx,1]),c='k',fontsize=12)
plt.show()

# %% [markdown]
# ## TSNE降维可视化

# %% [markdown]
# ### 可视化全部词条的二维Embedding¶

# %%
# 将Embedding用TSNE降维到2维
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, n_iter=1000)
embed_2d = tsne.fit_transform(X)
# Out:
# d:\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:, 0], embed_2d[:, 1])
plt.show()

# %% [markdown]
# ### 可视化全部词条和关键词条的二维Embedding

# %%
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:,0], embed_2d[:,1])

for item in terms_chosen:
    idx = term2index[item]
    plt.scatter(embed_2d[idx,0], embed_2d[idx,1],c='r',s=50)
    plt.annotate(item, xy=(embed_2d[idx,0], embed_2d[idx,1]),c='k',fontsize=12)
plt.show()

# %%
embed_2d.shape
# Out:
# (559, 2)

# %% [markdown]
# ### 导出TSNE降维到二维之后的Embedding

# %%
terms_chosen_mask = np.zeros(X.shape[0])
for item in terms_chosen:
    idx = term2index[item]
    terms_chosen_mask[idx] = 1

# %%
df = pd.DataFrame()
df['X'] = embed_2d[:,0]
df['Y'] = embed_2d[:,1]
df['item'] = model.wv.index_to_key
df['pagerank'] = pagerank.values()
df['chosen'] = terms_chosen_mask

# %%
df
# Out:
#              X          Y   item  pagerank  chosen
# 0   -25.019192 -10.875401  音乐分享官  0.032587     1.0
# 1    -9.696004  -6.255538     音乐  0.048502     1.0
# 2    -9.108784  16.486050   乐评盘点  0.000755     1.0
# 3    13.461567  -4.089142    二次元  0.041230     1.0
# 4   -17.867916   9.962457   动漫音乐  0.005284     1.0
# ..         ...        ...    ...       ...     ...
# 554  -7.954473  -5.504809     韩红  0.000755     0.0
# 555   7.745606  -0.547825     炮姐  0.000755     0.0
# 556   3.611481  -4.083079    DNA  0.000755     0.0
# 557  -1.484186 -12.788074   男声翻唱  0.000755     0.0
# 558  13.156192 -13.423384      萌  0.000755     0.0
#
# [559 rows x 5 columns]

# %%
df.to_csv('tsne_vis_2d.csv',index=False)
