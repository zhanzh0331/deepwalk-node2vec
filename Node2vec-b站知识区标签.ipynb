# %% [markdown]
# # b站-Node2Vec图嵌入

# %% [markdown]
# ## 安装工具包

# %%
# !pip install node2vec networkx numpy matplotlib

# %% [markdown]
# ## 导入工具包

# %%
import networkx as nx # 图数据挖掘
import numpy as np # 数据分析
import random # 随机数

# 数据可视化
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签  
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号
import pandas as pd

# %% [markdown]
# ## 导入数据集

# %%
# 空手道俱乐部数据集
# G = nx.karate_club_graph()

# %%
df = pd.read_csv("./data/bilibili_tag2.csv", sep="\t")
print(df.isnull().sum())
df = df.dropna()
G = nx.from_pandas_edgelist(df,df.columns[0], df.columns[1], create_using=nx.Graph())
# Out:
# A    0
# B    0
# dtype: int64

# %%
G.nodes
# Out:
# NodeView(('科技', '万物研究所', '知识', '科学科普', '人类史', '科学史', 'FOXP2', '智人', '科技史', '工具', '原始人', '走出非洲', '尼安德特人', '万物研究所·第九期', '生物', '科学', '科普', '自然', '万物研究所·第十期', '鉴定', '人工智能', '互联网', '学习', '流行音乐', '华语音乐', '研究', '数据', '傅里叶变换', '万物研究所·第七期', '深度学习', '眼镜', '医学', '健康', '搞笑', '医案寻踪', '骗局', '沙雕', '近视', '万物研究所·2022第五期', '灾难', '非洲', '疾病', '埃博拉病毒', '瘟疫', '病毒', '化学', '实验', '鸡', '坤坤', 'ikun', '鸡你太美', '我们都爱搞学习', '高考', '校园学习', '复习', '高中', '高中生物', '经验分享', '学习心得', '我们都爱搞学习·第二期', '考试', '大学', '校园', '学生党', '摆烂', '必剪创作', '基础知识', '易错点', '知识点', '恐龙', '剪辑', '生命', '古生物', '史前星球', '年表', '打卡挑战', '复习提纲朗读', '知识点梳理朗读', '初中生物', '中考生物', '生物知识点', '社会洞察计划', '冷知识', '人文', '社科·法律·心理', '趣闻', '星海计划', '干货', '大力王', '心理学知识', '高三', '课程', '逆袭', '遗传', '天文', '地理', '量子', '祖师爷', '全能打卡挑战', '天文学', '科学很可爱', '科学中穿梭', '历史的遗憾', '遗憾', '科学家', '涨知识', '2023科学很可爱', '正经的知识又增加了', '视频教程', '儿童', '少儿', '儿童教育', '宇宙', '休谟问题', '贝叶斯主义', '奥卡姆剃刀', '进化论', '科学哲学', '贝叶斯', '知识分享官', '物理', '物质', '科学实验', '心理学', '社会', '女生', '记忆力', '男生', '思维', '自信', '历史', '影视', '影视杂谈', '影视指南官', '纪录片', '自我提升', '影娱哔哔官', '太空', '星系', '探索', '光速', '社会观察局', '动力', '多巴胺', '自律', '戒瘾', '内耗', '社科人文分享官·第二期', '说说心理话', '自制', '心理', '读书', '原创', '职场', '成熟', '人际关系', '社交', '沟通', '内心强大', 'ChatGPT研究所', '计算机', 'AI', '数学', '原理', 'ChatGPT', '生产力', 'GPT', 'AI技能', 'AIGC', '动画短片', '动画', '综合', '教育', '早教', '十万个为什么', '科普启蒙', '动画短片群星计划', '手书', '短片', '短片·手书·配音', '分镜', '原创动画', '剧情', '欧美', '英配', '治愈系', '公益', '公平', '大学生', '寒门子弟', '生活', '日常', '伪常识', '伪知识', '辟谣', '颠覆', '谣言', '好奇心计划', '常识', '动物观察局', '动物圈', '动物二创', '猴子', '猴干', '母猴', '灵长类', '动物观察局21.0 小动物集合啦', '学习帮帮团', '背书', '英语', '英语听力', '英语口语', '英语学习', '有趣', '益智', '小学科学', '戒色', '肾虚', '记录出行的快乐', '摄影', '旅游', '出行', '治愈', '旅行', '风景', '夏天', '氛围', '记录', '一起fun放假', '旅拍', '新疆', '旅行VLOG', '夏日玩乐小分队', '冥想', '4K', '音乐', '音乐综合', '大自然', '治愈向', '森林', '地球', '放松电影', '自然风光', '放松音乐', '打造我的好身材', '运动', '健身', 'yoga nidra', '瑜伽放松术', '放松', '午睡', '失眠', '睡眠', '休息', '自然科学', '微观', '趣味动画', '微观世界', '水流', '相机', '野生技术协会', '技术宅', '数码', '技术', '教程', '生活里的美好瞬间', '淘出一万种生活', '仙境', '安静', '忘记烦恼', 'UP影剧综指南·剧好看', '影视混剪', '影视剪辑', 'UP影剧综指南', '电影混剪', '混剪', '美剧混剪', 'Star Sky', '人类群星闪耀时', '工业', '人物', '钢铁产业', '钢铁', '产业', '冶金', '昆虫', '蚂蚁', '萝王', '国宝帮', '古钱', '春日迷影电影院', '美国电影', '电影解说', '亲情', '励志', '电影', '白日梦想家', '影娱新春游园会', '野生技能协会', '全程高能', '文化', '天天鉴宝', '西藏', '惊吓', '鉴宝', '网络热门鉴定', '黑科技', '直播带货', '翻车', '神器', '热门', '智商税', '爆款', '网络热门', '原创歌曲', '奇妙生物大赏', '原创音乐', '古董', '收藏', '古玩', '牛道德', '计算机技术', '神经网络', '计算机视觉', '机器学习', 'OpenCV', '人工智能课程', '人工智能实战', '专升本', '学习必备', '乾坤未定，你我皆是黑马！', '加油，少年郎！', '畅聊行业观点', '经济', '金融', '财经商业', '生成式AI', '大语言模型', '寻找100位内行人', '商业', '手机', '行业', '第一', 'vivo', 'CV', '科技猎手', '自然语言处理', '计算机科学', '卷积神经网络', '人工智能学习路线', '科技猎手计划·2022第四期', '科技猎手2023', '航空', 'DIY', '极客DIY', '军事', '游戏', '模拟', '神经元', '强化学习', '监督学习', '知识分享官2021第九期', '趣味科普人文', '防骗', '寒假Vlog-一起学习吧', '编程', '程序员', '前端', '互联网原理', 'web开发', 'TCP//IP', '编程入门', '零基础编程', '1024程序员节', 'PYTHON入门', '中文字幕', '恶搞', 'TheMrNICEGUY', '奶思盖', '段子', '人文历史', '是老师，也是UP主！', '理由', '张学友', '刘德华', '经典老歌', '经典歌曲', '怀旧', '##全能音乐挑战赛##', '华语歌曲', '精选歌单', '开口跪', '音乐现场', '演唱会', '必看', '封神', '吻别', '音乐私藏馆', '五月天', '林俊杰', '周杰伦', '童年回忆杀', '七里香', '晴天', '回忆向', '童年', 'Super Star', '遇见', 'MV', '飞行日', '刘若英飞行日演唱会', '刘若英', '音乐分享官', '黄家驹', '乐评盘点', '榜单', '经典', '邓丽君', '华语', '音乐分享官5.0', '极乐净土', '二次元', 'ACG音乐', '动漫音乐', 'One last kiss', '音乐分享官7.0', '美依礼芽', '群青', 'B站神曲', '2022年度音乐盘点', '年度盘点', '年度音乐盘点', '最佳歌曲', '张韶涵', '鞠婧祎', '薛之谦', '明星', '歌曲', '告五人', '存档2022，开拍2023', '学习动力', 'STUDYWITHME', '背景音乐', 'STUDYACCOUNT', '油管', '搬运', '音乐安利大赏', '杨丞琳', '毕业季', '毕业', '青春', '中国', '齐秦', '资讯', 'KPOP人集合企划', '学习日常打卡', '校园vlog', 'vlog', '备考', '高效', '实时学习', '非正式颁奖小会', '校园分享官', '白噪音', '学习向', '自习', 'STUDY', '学习打卡', '小剧场', '励志短片', '梦想', '奋斗', '正能量', '激励', '励志向', '努力', '微电影', '科幻', '下饭', '短剧', '持续更新', '连载', '视频', '学习方法', '考研', '学霸', '音乐选集', '无损音质', '好听的歌曲', '歌曲合集', '流行歌曲', '好听的歌', '校园歌曲', 'bilibili过大年', '高质量', '歌单', '经典音乐', '高音质', '音乐热歌', '欧美流行', '经典英文歌', '欧美流行音乐', '超好听英文歌曲', '英文歌合集', '音乐素人投稿季', '每天一个科研小知识', '研究生', '科研', '博士', '硕博', '硕士', '读研', '文献', '组会', '毕业论文', '论文', ...

# %%
len(G)
# Out:
# 1234

# %%
# 可视化
plt.figure(figsize=(15,14))
pos = nx.spring_layout(G, seed=5)
nx.draw(G, pos, with_labels=False)
plt.show()

# %% [markdown]
# ## 构建Node2Vec模型

# %%
from node2vec import Node2Vec

# %%
# 设置node2vec参数
node2vec = Node2Vec(G, 
                    dimensions=32,  # 嵌入维度
                    p=1,            # 回家参数
                    q=0.5,          # 外出参数
                    walk_length=5, # 随机游走最大长度
                    num_walks=100,  # 每个节点作为起始节点生成的随机游走个数
                    workers=4       # 并行线程数
                   )

# p=1, q=0.5, n_clusters=6。DFS深度优先搜索，挖掘同质社群
# p=1, q=2, n_clusters=3。BFS宽度优先搜索，挖掘节点的结构功能。

# 训练Node2Vec，参数文档见 gensim.models.Word2Vec
model = node2vec.fit(window=1,    # Skip-Gram窗口大小
                     min_count=1,  # 忽略出现次数低于此阈值的节点（词）
                     batch_words=4 # 每个线程处理的数据量
                    )
X = model.wv.vectors
# Out:
# Computing transition probabilities:   0%|          | 0/1234 [00:00<?, ?it/s]

# %%
X.shape
# Out:
# (1234, 32)

# %% [markdown]
# ## 节点Embedding聚类可视化

# %% [markdown]
# ### 运行聚类
#
# Kmeans聚类算法讲解：https://www.bilibili.com/video/BV1HJ411P7cs

# %%
# # DBSCAN聚类
# from sklearn.cluster import DBSCAN
# cluster_labels = DBSCAN(eps=0.5, min_samples=6).fit(X).labels_
# print(cluster_labels)

# KMeans聚类
from sklearn.cluster import KMeans
import numpy as np
cluster_labels = KMeans(n_clusters=3).fit(X).labels_
print(cluster_labels)
# Out:
# [1 1 0 ... 1 1 1]

# %% [markdown]
# ### 将networkx中的节点和词向量中的节点对应
#
# 将词汇表的节点顺序转为networkx中的节点顺序

# %%
colors = []
nodes = list(G.nodes)
for node in nodes: # 按 networkx 的顺序遍历每个节点
    idx = model.wv.key_to_index[str(node)] # 获取这个节点在 embedding 中的索引号
    colors.append(cluster_labels[idx]) # 获取这个节点的聚类结果

# %% [markdown]
# ### 可视化聚类效果

# %%
plt.figure(figsize=(15,14))
pos = nx.spring_layout(G, seed=10)
nx.draw(G, pos, node_color=colors, with_labels=True)
plt.show()

# %% [markdown]
# ## 查看Embedding

# %%
model.wv.get_vector('手机').shape
# Out:
# (32,)

# %%
# 查看某个节点的Embedding
model.wv.get_vector('手机')
# Out:
# array([ 7.4415199e-02, -1.2434044e+00, -4.0288779e-01,  3.9708507e-01,
#        -3.1712630e-01,  2.4588291e-01,  7.5378001e-01,  1.2656283e+00,
#        -2.7425230e-01, -1.7355381e-01,  4.3856275e-01, -1.6927601e+00,
#         5.3710145e-01, -2.7757126e-01, -1.2774432e-01, -2.0243116e-01,
#        -2.6541203e-02, -1.9007327e-01, -1.0635378e-03, -2.7471083e-01,
#         2.4982642e-01,  1.9859178e+00,  1.2074323e+00, -1.9821005e-01,
#        -8.3868831e-01, -7.5593036e-01, -1.1583730e+00, -1.2208326e-01,
#         5.1281375e-01, -7.0413131e-01,  2.2039250e-01, -5.7917392e-01],
#       dtype=float32)

# %%
# 查找节点的相似节点
model.wv.most_similar('数码')
# Out:
# [('技术宅', 0.8332101106643677),
#  ('手机', 0.7916712760925293),
#  ('科技猎手计划2022第二季', 0.7876229286193848),
#  ('野生技术协会', 0.772271454334259),
#  ('APP推荐', 0.7510901689529419),
#  ('漫画', 0.7488031983375549),
#  ('PYTHON教程', 0.744411289691925),
#  ('运营产品', 0.7425751090049744),
#  ('大数据', 0.7396265268325806),
#  ('加速器', 0.7380245327949524)]

# %%
# 查看任意两个节点的相似度
model.wv.similarity('数码', '手机')
# Out:
# 0.7916713

# %%
# 查看任意两个节点的相似度DIY
model.wv.similarity('数码', '电影')
# Out:
# 0.15868579

# %% [markdown]
# ## 对Edge（连接）做Embedding

# %%
from node2vec.edges import HadamardEmbedder

# %%
# Hadamard 二元操作符：两个 Embedding 对应元素相乘
edges_embs = HadamardEmbedder(keyed_vectors=model.wv)

# %%
# 查看 任意两个节点连接 的 Embedding
edges_embs[('数码', '电影')]
# Out:
# array([-0.01568311,  0.18288156, -0.02559192, -0.12382559, -0.35254   ,
#        -0.03021579,  0.3229161 , -0.33555236,  0.08366509,  0.12680465,
#         0.11087055,  0.76437926,  0.5802587 , -0.06076343,  0.01241119,
#        -0.12185465,  0.06949055, -0.03578024, -0.20406483, -0.26870006,
#         0.48239502,  0.5944515 ,  0.59820205,  0.02485037, -0.02866535,
#        -0.02056831,  0.51198334, -0.16324204, -0.6165018 , -0.05978726,
#        -0.02032008,  0.00360279], dtype=float32)

# %%
# 计算所有 Edge 的 Embedding
edges_kv = edges_embs.as_keyed_vectors()
# Out:
# Generating edge features: 100%|██████████████████████████████████████████| 761995/761995.0 [00:04<00:00, 157721.70it/s]

# %%
edges_kv.index_to_key
# Out:
# ["('科普', '科普')",
#  "('知识', '科普')",
#  "('数据', '科普')",
#  "('学习', '科普')",
#  "('眼镜', '科普')",
#  "('人文', '科普')",
#  "('华语音乐', '科普')",
#  "('科普', '自然')",
#  "('沙雕', '科普')",
#  "('科学科普', '科普')",
#  "('科学', '科普')",
#  "('冷知识', '科普')",
#  "('健康', '科普')",
#  "('研究', '科普')",
#  "('流行音乐', '科普')",
#  "('搞笑', '科普')",
#  "('科普', '非洲')",
#  "('人工智能', '科普')",
#  "('瘟疫', '科普')",
#  "('深度学习', '科普')",
#  "('社会洞察计划', '科普')",
#  "('ikun', '科普')",
#  "('科普', '鸡你太美')",
#  "('科普', '鉴定')",
#  "('灾难', '科普')",
#  "('社科·法律·心理', '科普')",
#  "('万物研究所·第十期', '科普')",
#  "('生物', '科普')",
#  "('万物研究所·第七期', '科普')",
#  "('生活', '科普')",
#  "('互联网', '科普')",
#  "('科普', '骗局')",
#  "('科普', '近视')",
#  "('医案寻踪', '科普')",
#  "('万物研究所', '科普')",
#  "('医学', '科普')",
#  "('科普', '高考')",
#  "('科普', '鸡')",
#  "('病毒', '科普')",
#  "('傅里叶变换', '科普')",
#  "('科普', '音乐')",
#  "('坤坤', '科普')",
#  "('埃博拉病毒', '科普')",
#  "('万物研究所·2022第五期', '科普')",
#  "('科技', '科普')",
#  "('疾病', '科普')",
#  "('实验', '科普')",
#  "('化学', '科普')",
#  "('知识分享官', '科普')",
#  "('校园学习', '科普')",
#  "('历史', '科普')",
#  "('科普', '资讯')",
#  "('科普', '黑科技')",
#  "('动感视频', '科普')",
#  "('冥想', '科普')",
#  "('科普', '音乐分享官')",
#  "('服饰', '科普')",
#  "('星海计划', '科普')",
#  "('2022年度音乐盘点', '科普')",
#  "('电视剧解说', '科普')",
#  "('动画短片群星计划', '科普')",
#  "('科普', '考试')",
#  "('毕业季', '科普')",
#  "('春日穿搭指南', '科普')",
#  "('星计划', '科普')",
#  "('科普', '计算机')",
#  "('科普', '鬼畜大赏')",
#  "('科普', '经济')",
#  "('AI魔法研究中心', '科普')",
#  "('科普', '趣闻')",
#  "('一起记录2022', '科普')",
#  "('万物皆可游戏', '科普')",
#  "('女神异闻录5', '科普')",
#  "('新学期的正确打开方式', '科普')",
#  "('学习日常打卡', '科普')",
#  "('开学焕新妆', '科普')",
#  "('科普', '记录出行的快乐')",
#  "('用知识过好新的一年', '科普')",
#  "('日常', '科普')",
#  "('2023健身FLAG', '科普')",
#  "('ChatGPT研究所', '科普')",
#  "('万恶之源', '科普')",
#  "('动物观察局', '科普')",
#  "('张学友', '科普')",
#  "('11月美食碎片打卡', '科普')",
#  "('短片', '科普')",
#  "('科普', '纪实')",
#  "('正经的知识又增加了', '科普')",
#  "('摄影', '科普')",
#  "('生活里的美好瞬间', '科普')",
#  "('和我一起唱歌吧', '科普')",
#  "('科普', '美好生活日常记录')",
#  "('畅聊行业观点', '科普')",
#  "('动画短片', '科普')",
#  "('人类迷惑行为', '科普')",
#  "('宇宙', '科普')",
#  "('社会观察局', '科普')",
#  "('功夫', '科普')",
#  "('科普', '编程')",
#  "('科技猎手', '科普')",
#  "('技术宅的夏天', '科普')",
#  "('搞笑新星训练营', '科普')",
#  "('切磋亿下！', '科普')",
#  "('搞笑研究所', '科普')",
#  "('科普', '网络热门鉴定')",
#  "('科普', '英语学习')",
#  "('动画', '科普')",
#  "('故事档案馆', '科普')",
#  "('人力VOCALOID', '科普')",
#  "('校园唠嗑会', '科普')",
#  "('科普', '课堂教育')",
#  "('教育学', '科普')",
#  "('学习帮帮团', '科普')",
#  "('影视', '科普')",
#  "('每天一个科研小知识', '科普')",
#  "('我们都爱搞学习', '科普')",
#  "('科普', '蔡徐坤')",
#  "('科学很可爱', '科普')",
#  "('科技猎手2023', '科普')",
#  "('五月天', '科普')",
#  "('原创', '科普')",
#  "('社会', '科普')",
#  "('科普', '鬼畜')",
#  "('生命', '科普')",
#  "('必剪创作', '科普')",
#  "('人文历史', '科普')",
#  "('科普', '鬼畜星探企划')",
#  "('打卡挑战', '科普')",
#  "('教育', '科普')",
#  "('大学', '科普')",
#  "('游戏', '科普')",
#  "('中国', '科普')",
#  "('2022高考季', '科普')",
#  "('2023读书日', '科普')",
#  "('科普', '经验分享')",
#  "('是老师，也是UP主！', '科普')",
#  "('2023高考季', '科普')",
#  "('科普', '高中')",
#  "('娱乐', '科普')",
#  "('科普', '记录')",
#  "('科普', '美食')",
#  "('公开课', '科普')",
#  "('科普', '计算机技术')",
#  "('一起上岸吧', '科普')",
#  "('2022高考加油', '科普')",
#  "('物理', '科普')",
#  "('文学', '科普')",
#  "('二次元', '科普')",
#  "('数码', '科普')",
#  "('科普', '野生技能协会')",
#  "('哲学', '科普')",
#  "('科普', '英语听力')",
#  "('大学生', '科普')",
#  "('学习心得', '科普')",
#  "('乐评盘点', '科普')",
#  "('时尚', '科普')",
#  "('AI', '科普')",
#  "('科普', '魔性')",
#  "('科普', '高考化学')",
#  "('MV', '科普')",
#  "('科普', '高能')",
#  "('数学', '科普')",
#  "('科普', '鬼畜调教')",
#  "('科普', '考研')",
#  "('短片·手书·配音', '科普')",
#  "('科普', '美国')",
#  "('科普', '翻唱')",
#  "('科普', '英语')",
#  "('科普', '财经商业')",
#  "('校园', '科普')",
#  "('天文', '科普')",
#  "('我生命里的一分钟', '科普')",
#  "('科普', '自然科学')",
#  "('影视剪辑', '科普')",
#  "('教程', '科普')",
#  "('剧情', '科普')",
#  "('文化', '科普')",
#  "('科普', '音乐综合')",
#  "('分享', '科普')",
#  "('科普', '经典')",
#  "('科普', '自制')",
#  "('影视杂谈', '科普')",
#  "('科普', '穿搭')",
#  "('商业', '科普')",
#  "('原创音乐', '科普')",
#  "('科普', '音乐分享官7.0')",
#  "('科普', '野生技术协会')",
#  "('2023科学很可爱', '科普')",
#  "('原创歌曲', '科普')",
#  "('剪辑', '科普')",
#  "('科普', '逗比')",
#  "('治愈', '科普')",
#  "('歌曲', '科普')",
#  "('科普', '运动')",
#  "('健身', '科普')",
#  "('洗脑循环', '科普')",
#  "('科幻', '科普')",
#  "('旅游', '科普')",
#  "('学生党', '科普')",
#  "('人物', '科普')",
#  "('奇葩', '科普')",
#  "('出行', '科普')",
#  "('原理', '科普')",
#  "('心理', '科普')",
#  "('科普', '绘画')",
#  "('我在B站跨年', '科普')",
#  "('手机游戏', '科普')",
#  "('全程高能', '科普')",
#  "('科普', '高三')",
#  "('生活记录', '科普')",
#  "('作文', '科普')",
#  "('心理学', '科普')",
#  "('手书', '科普')",
#  "('开口跪', '科普')",
#  "('科普', '鬼畜剧场')",
#  "('vlog', '科普')",
#  "('科普', '黑人')",
#  "('恶搞', '科普')",
#  "('复习', '科普')",
#  "('科普', '计算机视觉')",
#  "('OpenCV', '科普')",
#  "('下饭', '科普')",
#  "('模拟', '科普')",
#  "('夏天', '科普')",
#  "('科普', '软件应用')",
#  "('涨知识', '科普')",
#  "('技术宅', '科普')",
#  "('机器学习', '科普')",
#  "('科普', '遗传')",
#  "('神曲', '科普')",
#  "('科普', '读书')",
#  "('治愈系', '科普')",
#  "('科普', '音乐现场')",
#  "('新年要有新知识', '科普')",
#  "('动物观察局21.0 小动物集合啦', '科普')",
#  "('科普', '美妆护肤')",
#  "('搭配', '科普')",
#  "('年度音乐盘点', '科普')",
#  "('UP！新学期', '科普')",
#  "('万物研究所·第九期', '科普')",
#  "('科普', '趣味科普人文')",
#  "('原创动画', '科普')",
#  "('治愈向', '科普')",
#  "('科普', '风景')",
#  "('科普', '颜值')",
#  "('科普', '萌宠')",
#  "('有趣', '科普')",
#  "('科普', '青春')",
#  "('科普', '鬼畜素材')",
#  "('动物圈', '科普')",
#  "('1分钟学个知识点', '科普')",
#  "('下厨挑战计划', '科普')",
#  "('林俊杰', '科普')",
#  "('科普', '课程')",
#  "('案件', '科普')",
#  "('一起fun放假', '科普')",
#  "('单机游戏', '科普')",
#  "('科普', '篮球')",
#  "('科普', '量子')",
#  "('地理', '科普')",
#  "('干货', '科普')",
#  "('P5', '科普')",
#  "('科普', '综合')",
#  "('科普', '经典歌曲')",
#  "('收藏', '科普')",
#  "('科普', '线上课堂')",
#  "('周杰伦', '科普')",
#  "('科技猎手计划2022第二季', '科普')",
#  "('睡眠', '科普')",
#  "('服装搭配', '科普')",
#  "('RAP', '科普')",
#  "('影评', '科普')",
#  "('励志', '科普')",
#  "('科普', '语文')",
#  "('眼睛', '科普')",
#  "('科普', '说唱')",
#  "('科普', '英语口语')",
#  "('欧美', '科普')",
#  "('手工', '科普')",
#  "('切磋亿下', '科普')",
#  "('歪果仁', '科普')",
#  "('研究生', '科普')",
#  "('科普', '鬼畜大赏2020-鬼畜调教')",
#  "('数据可视化', '科普')",
#  "('沙雕视频', '科普')",
#  "('科普', '视频')",
#  "('旅行', '科普')",
#  "('科普', '鼠疫')",
#  "('沙雕广告', '科普')",
#  "('科普', '震撼')",
#  "('影视混剪', '科普')",
#  "('科普', '舞蹈')",
#  "('科普', '童年')",
#  "('影娱新春游园会', '科普')",
#  "('惊悚', '科普')",
#  "('手机', '科普')",
#  "('Python', '科普')",
#  "('科普', '防骗')",
#  "('我们都爱搞学习·第二期', '科普')",
#  "('生物学', '科普')",
#  "('只因', '科普')",
#  "('泰裤辣', '科普')",
#  "('是在下输了', '科普')",
#  "('动漫', '科普')",
#  "('人生', '科普')",
#  "('混剪', '科普')",
#  "('流感', '科普')",
#  "('科普', '金融')",
#  "('科普', '资本')",
#  "('天花', '科普')",
#  "('寻找100位内行人', '科普')",
#  "('人工智能实战', '科普')",
#  "('埃博拉', '科普')",
#  "('卷积神经网络', '科普')",
#  "('名场面', '科普')",
#  "('新冠肺炎', '科普')",
#  "('实时学习', '科普')",
#  "('科普', '童年回忆杀')",
#  "('小剧场', '科普')",
#  "('神经网络', '科普')",
#  "('科普', '马尔堡')",
#  "('搞笑视频', '科普')",
#  "('新型冠状病毒', '科普')",
#  "('科普', '镜流')",
#  "('段子', '科普')",
#  "('神经', '科普')",
#  "('恐怖', '科普')",
#  "('减肥', '科普')",
#  "('科普', '科研')",
#  "('毕业歌曲', '科普')",
#  "('动物世界', '科普')",
#  "('化妆技巧', '科普')",
#  "('物质', '科普')",
#  "('热点', '科普')",
#  "('小鬼', '科普')",
#  "('吐槽', '科普')",
#  "('新年快乐，好久不见！', '科普')",
#  "('人工智能课程', '科普')",
#  "('正能量', '科普')",
#  "('可爱', '科普')",
#  "('女生', '科普')",
#  "('崩坏：星穹铁道', '科普')",
#  "('古生物', '科普')",
#  "('科普', '美妆')",
#  "('传染病', '科普')",
#  "('科普', '视频教程')",
#  "('吸管', '科普')",
#  "('科普', '自律')",
#  "('工业', '科普')",
#  "('科普', '纪录片')",
#  "('早餐', '科普')",
#  "('科学史', '科普')",
#  "('电路', '科普')",
#  "('医学生', '科普')",
#  "('极客DIY', '科普')",
#  "('新手化妆', '科普')",
#  "('情感', '科普')",
#  "('家常菜', '科普')",
#  "('科普', '飞行日')",
#  "('喵太社', '科普')",
#  "('可达鸭', '科普')",
#  "('崩坏：星穹铁道创作者激励计划', '科普')",
#  "('科普', '美食记录')",
#  "('学霸', '科普')",
#  "('DIY', '科普')",
#  "('科学实验', '科普')",
#  "('暗猫', '科普')",
#  "('人类', '科普')",
#  "('日常妆容', '科普')",
#  "('干饭人', '科普')",
#  "('免疫系统', '科普')",
#  "('亲爱的旅人啊', '科普')",
#  "('全能打卡挑战', '科普')",
#  "('祖师爷', '科普')",
#  "('社科人文分享官·第二期', '科普')",
#  "('科普', '辟谣')",
#  "('干杯', '科普')",
#  "('午睡', '科普')",
#  "('UP影剧综指南·剧好看', '科普')",
#  "('科普', '音乐私藏馆')",
#  "('吻别', '科普')",
#  "('清华大学', '科普')",
#  "('技术', '科普')",
#  "('万物研究所·第八期', '科普')",
#  "('2020毕业季', '科普')",
#  "('喵星人', '科普')",
#  "('倪大红', '科普')",
#  "('景元', '科普')",
#  "('FASHION', '科普')",
#  "('军事', '科普')",
#  "('教师编', '科普')",
#  "('科普', '薛之谦')",
#  "('科普', '通往群星的轨道')",
#  "('教师资格证', '科普')",
#  "('听歌', '科普')",
#  "('北京东路的日子', '科普')",
#  "('B站神曲', '科普')",
#  "('科普', '航空')",
#  "('yoga nidra', '科普')",
#  "('入海', '科普')",
#  "('喜剧', '科普')",
#  "('科学哲学', '科普')",
#  "('科普', '群青')",
#  "('日常妆', '科普')",
#  "('科普', '翻唱挑战赛')",
#  "('梁非凡', '科普')",
#  "('四六级', '科普')",
#  "('伤感', '科普')",
#  "('科普', '罪案')",
#  "('科普', '谣言')",
#  "('科普', '配色')",
#  "('科普', '雷区')",
#  "('科普', '观察动物')",
#  "('科普', '警察')",
#  "('封神', '科普')",
#  "('瑜伽放松术', '科普')",
#  "('科普', '编剧')",
#  "('学习向', '科普')",
#  "('科普', '长高')",
#  "('科普', '高中生物')",
#  "('PVZ', '科普')",
#  "('波澜哥', '科普')",
#  "('大学毕业', '科普')",
#  "('时尚穿搭', '科普')",
#  "('沙雕游戏', '科普')",
#  "('存档2022，开拍2023', '科普')",
#  "('科普', '陈宝国')",
#  "('#吐槽', '科普')",
#  "('瑜伽', '科普')",
#  "('失眠', '科普')",
#  "('科普', '美剧混剪')",
#  "('教师招聘', '科普')",
#  "('休息', '科普')",
#  "('法制', '科普')",
#  "('小奶猫', '科普')",
#  "('打造我的好身材', '科普')",
#  "('打工人晚餐', '科普')",
#  "('单曲', '科普')",
#  "('明星', '科普')",
#  "('五官', '科普')",
#  "('大明王朝1566', '科普')",
#  "('科普', '香港')",
#  "('星爷', '科普')",
#  "('破案', '科普')",
#  "('挑选眼镜', '科普')",
#  "('广告', '科普')",
#  "('动漫音乐', '科普')",
#  "('白听不厌', '科普')",
#  "('海瑞', '科普')",
#  "('服饰搭配', '科普')",
#  "('游戏唠嗑会', '科普')",
#  "('科普', '自习')",
#  "('真香', '科普')",
#  "('奥卡姆剃刀', '科普')",
#  "('放松', '科普')",
#  "('STUDY', '科普')",
#  "('电脑', '科普')",
#  "('科普', '贝叶斯')",
#  "('科普', '购物指南')",
#  "('时尚穿搭有态度', '科普')",
#  "('UP影剧综指南', '科普')",
#  "('SQL', '科普')",
#  "('科普', '穿搭分享')",
#  "('科普', '食谱')",
#  "('明朝', '科普')",
#  "('科普', '艺术')",
#  "('Life will change', '科普')",
#  "('科普', '鞠婧祎')",
#  "('喜之郎', '科普')",
#  "('科普', '虚数')",
#  "('眼镜框', '科普')",
#  "('和我一起唱歌吧4.0', '科普')",
#  "('科普', '贝叶斯主义')",
#  "('科普', '视力')",
#  "('演唱会', '科普')",
#  "('科普', '经典音乐')",
#  "('科普', '美依礼芽')",
#  "('电影剪辑', '科普')",
#  "('神仙打架', '科普')",
#  "('刘若英飞行日演唱会', '科普')",
#  "('好听', '科普')",
#  "('现场版', '科普')",
#  "('燃曲', '科普')",
#  "('新手教程', '科普')",
#  "('科普', '赵露思')",
#  "('科普', '面筋哥')",
#  "('One last kiss', '科普')",
#  "('嘉靖', '科普')",
#  "('无损音质', '科普')",
#  "('游戏音乐', '科普')",
#  "('公平', '科普')",
#  "('病理学', '科普')",
#  "('晒晒我的超高清视频', '科普')",
#  "('NovelAi', '科普')",
#  "('游戏版号', '科普')",
#  "('社会学', '科普')",
#  "('刑侦', '科普')",
#  "('拿铁', '科普')",
#  "('五月', '科普')",
#  "('一口气看完', '科普')",
#  "('科普', '进化论')",
#  "('科普', '鬼畜剧')",
#  "('帅哥', '科普')",
#  "('旅拍', '科普')",
#  "('114514', '科普')",
#  "('欧美音乐', '科普')",
#  "('必看', '科普')",
#  "('复古穿搭', '科普')",
#  "('科普', '运营产品')",
#  "('ACG音乐', '科普')",
#  "('情侣', '科普')",
#  "('日本大地震', '科普')",
#  "('偶像练习生', '科普')",
#  "('科普', '趣味短片')",
#  "('COVER', '科普')",
#  "('公益', '科普')",
#  "('事件', '科普')",
#  "('科普', '零基础编程')",
#  "('校园星发现·离谱专业大赏', '科普')",
#  "('暴雨', '科普')",
#  "('坑爹', '科普')",
#  "('微电影', '科普')",
#  "('MidJourney', '科普')",
#  "('告五人', '科普')",
#  "('审美', '科普')",
#  "('变美', '科普')",
#  "('原坤', '科普')",
#  "('科普', '超好听英文歌曲')",
#  "('校园分享官', '科普')",
#  "('探索', '科普')",
#  "('模型', '科普')",
#  "('年轻人', '科普')",
#  "('科普', '诊断公式')",
#  "('科普', '音乐选集')",
#  "('男生配饰', '科普')",
#  "('科普', '阴阳五行')",
#  "('瞬间', '科普')",
#  "('扶贫', '科普')",
#  "('专属', '科普')",
#  "('PYTHON入门', '科普')",
#  "('材料', '科普')",
#  "('种草', '科普')",
#  "('2022时尚年度盘点', '科普')",
#  "('数据清理', '科普')",
#  "('眼镜挑选', '科普')",
#  "('Torine Michelle', '科普')",
#  "('刘若英', '科普')",
#  "('可视化', '科普')",
#  "('回忆向', '科普')",
#  "('全网', '科普')",
#  "('科普', '鬼畜研究')",
#  "('男生穿搭教程', '科普')",
#  "('短剧', '科普')",
#  "('夏日玩乐小分队', '科普')",
#  "('PYTHON教程', '科普')",
#  "('神器', '科普')",
#  "('国风音乐', '科普')",
#  "('数据科学', '科普')",
#  "('科普', '镝数')",
#  "('惊吓', '科普')",
#  "('520', '科普')",
#  "('唐山大地震', '科普')",
#  "('科普', '魔改')",
#  "('回忆', '科普')",
#  "('科普', '科普纪录')",
#  "('害怕', '科普')",
#  "('植物大战戴夫', '科普')",
#  "('母猴', '科普')",
#  "('华语', '科普')",
#  "('学习打卡', '科普')",
#  "('科普', '自制动画')",
#  "('女神异闻录', '科普')",
#  "('故事', '科普')",
#  "('科普', '邓丽君')",
#  "('科普', '食品')",
#  "('科普', '高音质')",
#  "('科普', '音乐素人投稿季')",
#  "('一带一路', '科普')",
#  "('游戏资讯', '科普')",
#  "('百家讲坛', '科普')",
#  "('科普', '英文歌合集')",
#  "('安全', '科普')",
#  "('民族服饰', '科普')",
#  "('七里香', '科普')",
#  "('科普', '蟹肉棒')",
#  "('科普', '高质量')",
#  "('科普', '网红')",
#  "('外星人', '科普')",
#  "('休谟问题', '科普')",
#  "('人类学', '科普')",
#  "('科普', '零基础入门')",
#  "('科普', '长大后')",
#  "('晴天', '科普')",
#  "('现代文明', '科普')",
#  "('分析报告', '科普')",
#  "('科普', '网络')",
#  "('科普', '音mad')",
#  "('科普', '网络热门')",
#  "('寒门子弟', '科普')",
#  "('基础入门', '科普')",
#  "('科普', '穿搭教程')",
#  "('RNN循环神经网络', '科普')",
#  "('男士眼镜', '科普')",
#  "('#自然灾害', '科普')",
#  "('图表制作', '科普')",
#  "('极乐净土', '科普')",
#  "('杨超越', '科普')",
#  "('科普', '贝鲁特')",
#  "('王境泽', '科普')",
#  "('少数民族', '科普')",
#  "('1024程序员节', '科普')",
#  "('哦呼w', '科普')",
#  "('灵长类', '科普')",
#  "('游戏杂谈', '科普')",
#  "('Super Star', '科普')",
#  "('怀民亦未寝', '科普')",
#  "('碱性食物', '科普')",
#  "('科普', '鬼畜调教赛道')",
#  "('科普', '黑奴')",
#  "('动画短片群星计划 第七期', '科普')",
#  "('科普', '联合创作')",
#  "('白噪音', '科普')",
#  "('年度盘点', '科普')",
#  "('国产游戏', '科普')",
#  "('光速', '科普')",
#  "('古董', '科普')",
#  "('科普', '镜框')",
#  "('电影混剪', '科普')",
#  "('校园分享官第5期', '科普')",
#  "('科普', '穿搭公式')",
#  "('直播带货', '科普')",
#  "('华语歌曲', '科普')",
#  "('张韶涵', '科普')",
#  "('啊对对对', '科普')",
#  "('怪物', '科普')",
#  "('科普', '经典老歌')",
#  "('人力vocaloid', '科普')",
#  "('猴子', '科普')",
#  "('深度学习入门', '科普')",
#  "('数据分析自学', '科普')",
#  "('睡前故事', '科普')",
#  "('生存', '科普')",
#  "('乡村', '科普')",
#  "('单机', '科普')",
#  "('拯救丑衣服', '科普')",
#  "('AIGC启航计划', '科普')",
#  "('知识分享官2021第九期', '科普')",
#  "('科普', '记录我的2022')",
#  "('科普', '第五人格')",
#  "('万物研究所2022第三期', '科普')",
#  "('歌单', '科普')",
#  "('传统文化', '科普')",
#  "('热点观察局', '科普')",
#  "('AI绘画', '科普')",
#  "('家庭教育', '科普')",
#  "('社会观察局2022第二季', '科普')",
#  "('命理', '科普')",
#  "('广州黑人', '科普')",
#  "('大雨', '科普')",
#  "('科普', '隐私')",
#  "('科普', '鬼畜素材区')",
#  "('歪嘴战神', '科普')",
#  "('数据分析', '科普')",
#  "('书籍', '科普')",
#  "('MAD', '科普')",
#  "('好听的歌曲', '科普')",
#  "('六道', '科普')",
#  "('乾坤未定，你我皆是黑马！', '科普')",
#  "('数据删除', '科普')",
#  "('深度学习算法', '科普')",
#  "('石器时代', '科普')",
#  "('启蒙', '科普')",
#  "('犯罪心理学', '科普')",
#  "('富豪', '科普')",
#  "('好听的歌', '科普')",
#  "('科普', '道理')",
#  "('海啸', '科普')",
#  "('科普', '解说')",
#  "('漫画', '科普')",
#  "('仙剑奇侠传', '科普')",
#  "('大数据', '科普')",
#  "('StableDiffusion', '科普')",
#  "('科普', '职业职场')",
#  "('2022搞笑年度盛典', '科普')",
#  "('科普', '美食制作')",
#  "('科普', '递归神经网络')",
#  "('奇闻', '科普')",
#  "('整活', '科普')",
#  "('天天鉴宝', '科普')",
#  "('校园歌曲', '科普')",
#  "('八字', '科普')",
#  "('版号', '科普')",
#  "('科普', '解剖学')",
#  "('搞笑剪辑', '科普')",
#  "('##全能音乐挑战赛##', '科普')",
#  "('最佳歌曲', '科普')",
#  "('科普', '衡水体汉字')",
#  "('创意', '科普')",
#  "('大型纪录片', '科普')",
#  "('MAD.AMV', '科普')",
#  "('科普', '高度近视')",
#  "('Excel', '科普')",
#  "('医学英语', '科普')",
#  "('数据分析师', '科普')",
#  "('vivo', '科普')",
#  "('科普', '西方')",
#  "('玩具', '科普')",
#  "('影像', '科普')",
#  "('手办模玩', '科普')",
#  "('李永乐', '科普')",
#  "('叫嚣', '科普')",
#  "('科普', '空姐')",
#  "('特效向', '科普')",
#  "('小黑子', '科普')",
#  "('科普', '营销')",
#  "('国宝帮', '科普')",
#  "('牛道德', '科普')",
#  "('科普', '药理学')",
#  "('猴干', '科普')",
#  "('科普', '铁山靠')",
#  "('欧美流行', '科普')",
#  "('分镜', '科普')",
#  "('科普', '美国南北战争')",
#  "('政策', '科普')",
#  "('PV', '科普')",
#  "('欧美流行音乐', '科普')",
#  "('体育', '科普')",
#  "('中科院', '科普')",
#  "('科普', '音乐热歌')",
#  "('科普', '行业')",
#  "('科普', '美国龙卷风')",
#  "('bilibili过大年', '科普')",
#  "('宅舞', '科普')",
#  "('深度学习实战', '科普')",
#  "('爆款', '科普')",
#  "('三次方程', '科普')",
#  "('电池', '科普')",
#  "('科普', '蜜汁带感')",
#  "('bilibili新星计划', '科普')",
#  "('王琳凯', '科普')",
#  "('炸鸡', '科普')",
#  "('特摄', '科普')",
#  "('全国肿瘤防治宣传周', '科普')",
#  "('APP推荐', '科普')",
#  "('S.H.E', '科普')",
#  "('旅行VLOG', '科普')",
#  "('克苏鲁', '科普')",
#  "('科普', '血条')",
#  "('电化学', '科普')",
#  "('漂亮', '科普')",
#  "('变态', '科普')",
#  "('天文学', '科普')",
#  "('科普', '音乐分享官5.0')",
#  "('持续更新', '科普')",
#  "('爆笑', '科普')",
#  "('GAN对抗生成网络', '科普')",
#  "('科普', '黄家驹')",
#  "('科普', '请假')",
#  "('科普', '随手记录我的生活碎片')",
#  "('生产力', '科普')",
#  "('流行歌曲', '科普')",
#  "('奇闻趣事', '科普')",
#  "('科普', '音乐合伙人联盟企划')",
#  "('中国历史年表', '科普')",
#  "('I Wanna', '科普')",
#  "('科普', '连载')",
#  "('普法', '科普')",
#  "('民族', '科普')",
#  "('科普', '西班牙大流感')",
#  "('多素材', '科普')",
#  "('枪弹轨迹', '科普')",
#  "('中国风', '科普')",
#  "('同人配音', '科普')",
#  "('科普', '虾丸')",
#  "('植物大战僵尸', '科普')",
#  "('男孩', '科普')",
#  "('科普', '铁路')",
#  "('星系', '科普')",
#  "('广东', '科普')",
#  "('抗糖', '科普')",
#  "('推荐网站', '科普')",
#  "('刘德华', '科普')",
#  "('云南', '科普')",
#  "('小清新', '科普')",
#  "('歌曲合集', '科普')",
#  "('医学英语 人体解剖学和生理学', '科普')",
#  "('科普', '配镜')",
#  "('榜单', '科普')",
#  "('科普', '高考季')",
#  "('科普', '镝数图表')",
#  "('图表', '科普')",
#  "('科普', '英文')",
#  "('神经网络模型', '科普')",
#  "('数据挖掘', '科普')",
#  "('科普', '遇见')",
#  "('年轻', '科普')",
#  "('古玩', '科普')",
#  "('科普', '解剖')",
#  "('游戏推荐', '科普')",
#  "('科普', '衡水中学')",
#  "('政治', '科普')",
#  "('无糖饮料', '科普')",
#  "('弱碱水', '科普')",
#  "('科普', '高考地理')",
#  "('科普', '诈骗')",
#  "('科学3分钟', '科普')",
#  "('乳糖不耐受', '科普')",
#  "('只因你太美', '科普')",
#  "('书单', '科普')",
#  "('太空', '科普')",
#  "('mv', '科普')",
#  "('科普', '都市传说')",
#  "('科普', '肯尼亚')",
#  "('科普', '鬼谷闲谈')",
#  "('科普', '英语单词')",
#  "('剧情解析', '科普')",
#  "('科普', '霍乱')",
#  "('数据分析正式课程', '科普')",
#  "('搞笑吐槽', '科普')",
#  "('威力', '科普')",
#  "('爆炸', '科普')",
#  "('搞笑研究所9.0', '科普')",
#  "('神经网络算法', '科普')",
#  "('科普', '陈奕迅')",
#  "('科普', '锂电之父')",
#  "('明星舞蹈', '科普')",
#  "('科普', '锂电池')",
#  "('STUDYACCOUNT', '科普')",
#  "('万物研究所2022第二季', '科普')",
#  "('科普', '鉴宝')",
#  "('广州', '科普')",
#  "('科普', '趣味实验')",
#  "('沙雕作文', '科普')",
#  "('科普', '自然语言处理')",
#  "('挑战', '科普')",
#  "('电解液', '科普')",
#  "('国外疫情', '科普')",
#  "('拐卖', '科普')",
#  "('人文地理选择题', '科普')",
#  "('科普', '高等数学')",
#  "('科普', '自然风光')",
#  "('地理常', '科普')",
#  "('幸福', '科普')",
#  "('图鉴', '科普')",
#  "('小技巧', '科普')",
#  "('科普', '身体健康')",
#  "('科普', '鸡哥')",
#  "('插画', '科普')",
#  "('科普', '肿瘤')",
#  "('科普', '笑死人不偿命')",
#  "('女神', '科普')",
#  "('白内障', '科普')",
#  "('前端', '科普')",
#  "('神经网络与深度学习', '科普')",
#  "('加速器', '科普')",
#  "('奥特曼', '科普')",
#  "('不修音挑战赛', '科普')",
#  "('疑难杂症', '科普')",
#  "('今日校园', '科普')",
#  "('2021属我牛', '科普')",
#  "('怀旧', '科普')",
#  "('影娱哔哔官', '科普')",
#  "('ChatGPT', '科普')",
#  "('奴隶制', '科普')",
#  "('科普', '美剧')",
#  "('健康冷知识', '科普')",
#  "('才疏学浅的才浅', '科普')",
#  "('科普', '经济趋势')",
#  "('科普', '红斑狼疮')",
#  "('IKUN', '科普')",
#  "('学习帮帮团2022第二季', '科普')",
#  "('火山爆发', '科普')",
#  "('免疫', '科普')",
#  "('地球', '科普')",
#  "('科普', '西医综合')",
#  "('知识分享官·新年特别篇', '科普')",
#  "('快乐源泉', '科普')",
#  "('小学生沙雕作文', '科普')",
#  "('科普', '饮食')",
#  "('动物二创', '科普')",
#  "('科学启蒙', '科普')",
#  "('科普', '高中数学')",
#  "('科普', '肥胖')",
#  "('科普', '苏轼')",
#  "('4K', '科普')",
#  "('三农', '科普')",
#  "('环球', '科普')",
#  "('淘出一万种生活', '科普')",
#  "('刘福清', '科普')",
#  "('坤哥', '科普')",
#  "('医学知识', '科普')",
#  "('CV', '科普')",
#  "('宏观经济', '科普')",
#  "('毕业生', '科普')",
#  "('玩家', '科普')",
#  "('科普', '鬼畜小赏')",
#  "('PyTorch', '科普')",
#  "('末日', '科普')",
#  "('居家', '科普')",
#  "('新型冠状病毒感染的肺炎', '科普')",
#  "('病症', '科普')",
#  "('无糖可乐', '科普')",
#  "('努力', '科普')",
#  "('古钱', '科普')",
#  "('浙江大学', '科普')",
#  "('心理健康', '科普')",
#  "('奇闻异事', '科普')",
#  "('战争', '科普')",
#  "('科普', '通风')",
#  "('MAD·AMV', '科普')",
#  "('校园vlog', '科普')",
#  "('科普', '英文动画')",
#  "('科普', '规范')",
#  "('科普', '鲁迅')",
#  "('加油，少年郎！', '科普')",
#  "('昊京', '科普')",
#  "('numpy', '科普')",
#  "('生成式AI', '科普')",
#  "('科普', '经典英文歌')",
#  "('科普', '绝症')",
#  "('忘记烦恼', '科普')",
#  "('科普', '音乐相声')",
#  "('吴恩达', '科普')",
#  "('免费加速器', '科普')",
#  "('安静', '科普')",
#  "('深夜', '科普')",
#  "('房产', '科普')",
#  "('全明星', '科普')",
#  "('作文素材', '科普')",
#  "('临床医学', '科普')",
#  "('GPT', '科普')",
#  "('PYTORCH', '科普')",
#  "('涨姿势', '科普')",
#  "('癌症', '科普')",
#  "('健康养生', '科普')",
#  "('原始人', '科普')",
#  "('大全', '科普')",
#  "('科普', '钢铁')",
#  "('热门', '科普')",
#  "('动画嘉年华2023·灼夜花火', '科普')",
#  "('科普', '萌娃')",
#  "('易错点', '科普')",
#  "('演化', '科普')",
#  "('科普', '细菌')",
#  "('外国人', '科普')",
#  "('中文字幕', '科普')",
#  "('科普', '英配')",
#  "('科普', '网络安全')",
#  "('AIGC', '科普')",
#  "('科普', '鬼畜区')",
#  "('科普', '读研')",
#  "('毕业', '科普')",
#  "('科普', '简单')",
#  "('web开发', '科普')",
#  "('学习必备', '科普')",
#  "('科普', '高中地理')",
#  "('乐乐课堂', '科普')",
#  "('氛围', '科普')",
#  "('KPOP人集合企划', '科普')",
#  "('科普', '第一')",
#  "('科普', '编程入门')",
#  "('科普', '荔枝')",
#  "('科普', '齐秦')",
#  "('离谱', '科普')",
#  "('专升本', '科普')",
#  "('科普', '音乐安利大赏')",
#  "('互联网原理', '科普')",
#  "('科普', '雪distance')",
#  "('信号处理', '科普')",
#  "('科普', '高考加油')",
#  "('AMV', '科普')",
#  "('亲子', '科普')",
#  "('科普', '配音')",
#  "('神经元', '科普')",
#  "('特效', '科普')",
#  "('激励', '科普')",
#  "('知识点', '科普')",
#  "('AI技能', '科普')",
#  "('科普', '翻车')",
#  "('泰坦尼克号', '科普')",
#  "('新人', '科普')",
#  "('科普', '肺结核')",
#  "('我在B站做UP主', '科普')",
#  "('爆笑名场面', '科普')",
#  "('放松电影', '科普')",
#  "('科普', '高通滤波')",
#  "('分子生物学', '科普')",
#  "('科普', '轻食')",
#  "('人贩子', '科普')",
#  "('人类史', '科普')",
#  "('复习提纲朗读', '科普')",
#  "('小学生', '科普')",
#  "('大语言模型', '科普')",
#  "('中考化学', '科普')",
#  "('Tableau', '科普')",
#  "('年表', '科普')",
#  "('科普', '综漫')",
#  "('科普', '精选歌单')",
#  "('寒假', '科普')",
#  "('科普', '谭谈交通')",
#  ...]

# %%
# 查看 关系与 某两个节点 最相似的 节点对
edges_kv.most_similar(str(('数码', '电影')))
# Out:
# [("('亲情', '数码')", 0.9786699414253235),
#  ("('数码', '白日梦想家')", 0.9784155488014221),
#  ("('数码', '春日迷影电影院')", 0.9686092138290405),
#  ("('数码', '美国电影')", 0.9645354747772217),
#  ("('数码', '电影解说')", 0.9441916942596436),
#  ("('科技猎手计划2022第二季', '美好生活日常记录')", 0.8462245464324951),
#  ("('亲情', '教程')", 0.8421405553817749),
#  ("('电影', '野生技术协会')", 0.8400982618331909),
#  ("('影娱新春游园会', '数码')", 0.8350897431373596),
#  ("('亲情', '野生技术协会')", 0.8339124917984009)]

# %% [markdown]
# ## PCA降维可视化

# %% [markdown]
# ### 可视化全部词条的二维Embedding¶

# %%
X = model.wv.vectors

# %%
# 将Embedding用PCA降维到2维
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
embed_2d = pca.fit_transform(X)

# %%
embed_2d.shape
# Out:
# (1234, 2)

# %%
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:, 0], embed_2d[:, 1],s=15)
plt.show()

# %%
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:, 0], embed_2d[:, 1], c=colors, alpha=0.8,s=15)
plt.show()

# %% [markdown]
# ## TSNE降维可视化

# %% [markdown]
# ### 可视化全部词条的二维Embedding¶

# %%
# 将Embedding用TSNE降维到2维
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, n_iter=1000)
embed_2d = tsne.fit_transform(X)
# Out:
# D:\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# D:\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:, 0], embed_2d[:, 1],s=15)
plt.show()

# %%
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:, 0], embed_2d[:, 1], c=colors, alpha=0.8,s=15)
plt.show()

#可以看到TSNE降维可视化的效果更好一些

# %% [markdown]
# ### 可视化某个词条的二维Embedding

# %%
term = '手机'

# %%
term_256d = model.wv[term].reshape(1,-1)

# %%
term_256d.shape
# Out:
# (1, 32)

# %%
term_2d = pca.transform(term_256d)

# %%
term_2d
# Out:
# array([[0.5068206, 0.6546267]], dtype=float32)

# %%
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:,0], embed_2d[:,1],s=15)
plt.scatter(term_2d[:,0],term_2d[:,1],c='r',s=200)
plt.show()

# %% [markdown]
# ### 可视化某些词条的二维Embedding

# %%
# 计算PageRank重要度
pagerank = nx.pagerank(G)
# 从高到低排序
node_importance = sorted(pagerank.items(), key=lambda x:x[1], reverse=True)

# %%
# 取最高的前n个节点
n = 50
terms_chosen = []
for each in node_importance[:n]:
    terms_chosen.append(each[0])

# %%
# 手动补充新节点
# terms_chosen.extend(['computer vision','deep learning','convolutional neural network','convolution','natural-language processing','attention (machine learning)','support-vector machine','decision tree','random forest','computational imaging','machine vision','cognitive science','neuroscience','psychophysics','brain','visual cortex','visual neuroscience','cognitive model','finite difference','finite difference time domain','finite difference coefficients','finite difference methods for option pricing','iso 128','iso 10303'])

# %%
terms_chosen
# Out:
# ['知识',
#  '科普',
#  '学习',
#  '数据',
#  '科学科普',
#  '科学',
#  '眼镜',
#  '人文',
#  '自然',
#  '健康',
#  '沙雕',
#  '华语音乐',
#  '研究',
#  '冷知识',
#  '搞笑',
#  '流行音乐',
#  '人工智能',
#  '瘟疫',
#  '非洲',
#  '万物研究所·第十期',
#  'ikun',
#  '生物',
#  '深度学习',
#  '鸡你太美',
#  '社会洞察计划',
#  '社科·法律·心理',
#  '灾难',
#  '鉴定',
#  '万物研究所·第七期',
#  '生活',
#  '万物研究所',
#  '高考',
#  '互联网',
#  '骗局',
#  '病毒',
#  '鸡',
#  '近视',
#  '傅里叶变换',
#  '医案寻踪',
#  '坤坤',
#  '医学',
#  '埃博拉病毒',
#  '音乐',
#  '科技',
#  '疾病',
#  '万物研究所·2022第五期',
#  '实验',
#  '化学',
#  '知识分享官',
#  '校园学习']

# %% [markdown]
# ### 可视化全部词条和关键词条的二维Embedding

# %%
# 输入词条，输出词典中的索引号
term2index = model.wv.key_to_index

# %%
# index2term = model.wv.index_to_key
# term_index = np.array(term2index.values())

# %%
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:,0], embed_2d[:,1],s=15)

for item in terms_chosen:
    idx = term2index[item]
    plt.scatter(embed_2d[idx,0], embed_2d[idx,1],c='r',s=50)
    plt.annotate(item, xy=(embed_2d[idx,0], embed_2d[idx,1]),c='k',fontsize=15)
plt.show()

# %%
embed_2d.shape
# Out:
# (1234, 2)

# %% [markdown]
# ### 导出TSNE降维到二维之后的Embedding

# %%
terms_chosen_mask = np.zeros(X.shape[0])
for item in terms_chosen:
    idx = term2index[item]
    terms_chosen_mask[idx] = 1

# %%
df = pd.DataFrame()
df['X'] = embed_2d[:,0]
df['Y'] = embed_2d[:,1]
df['item'] = model.wv.index_to_key
df['pagerank'] = pagerank.values()
df['chosen'] = terms_chosen_mask

# %%
df
# Out:
#               X          Y   item  pagerank  chosen
# 0    -28.595535   9.394134     科普  0.005514     1.0
# 1    -13.661161 -10.213836     知识  0.007057     1.0
# 2     -6.135385  38.727604     数据  0.015731     1.0
# 3     -8.864642  -0.496154     学习  0.010548     1.0
# 4     21.201183 -28.260765     眼镜  0.000278     1.0
# ...         ...        ...    ...       ...     ...
# 1229   8.750114  -3.883238  白日梦想家  0.000282     0.0
# 1230 -27.233292   9.888939     早教  0.000282     0.0
# 1231 -12.910233  -9.756808     常识  0.000282     0.0
# 1232 -13.074399  -9.625574  好奇心计划  0.000271     0.0
# 1233 -12.977654  -9.721910     颠覆  0.000271     0.0
#
# [1234 rows x 5 columns]

# %%
df.to_csv('./res/b站科技区_node2vec_2d.csv',index=False)
