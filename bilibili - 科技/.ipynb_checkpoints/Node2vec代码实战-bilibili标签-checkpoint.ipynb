# %% [markdown]
# # b站-Node2Vec图嵌入
#
# ## 参考资料
#
# Elior Cohen代码：https://github.com/eliorc/node2vec
#
# Elior Cohen代码博客：https://maelfabien.github.io/machinelearning/graph_5/#graph-embedding
#
# 同济子豪兄：https://space.bilibili.com/1900783
#
# 2022-6-29

# %% [markdown]
# ## 安装工具包

# %%
# !pip install node2vec networkx numpy matplotlib

# %% [markdown]
# ## 导入工具包

# %%
import networkx as nx # 图数据挖掘
import numpy as np # 数据分析
import random # 随机数

# 数据可视化
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签  
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号
import pandas as pd

# %% [markdown]
# ## 导入数据集

# %%
# 空手道俱乐部数据集
# G = nx.karate_club_graph()

# %%
df = pd.read_csv("bilibili_tag.csv", sep="\t")
print(df.isnull().sum())
df = df.dropna()
G = nx.from_pandas_edgelist(df,df.columns[0], df.columns[1], create_using=nx.Graph())
# Out:
# A    0
# B    0
# dtype: int64

# %%
G.nodes
# Out:
# NodeView(('科技猎手', '科技猎手2023', '航空', 'DIY', '搞笑', '科技', '极客DIY', '黑科技', '手机', '软件应用', '数码', '知识', '科学科普', '智轨电车', '万物研究所·第十期', '中国制造', '必剪创作', '计算机技术', 'opporeno10', '科普', '人工智能', '科学', 'SOTA', '科工机械', '特种兵式旅游', '工程机械', '转场', '万物研究所', '人类史', '科学史', 'FOXP2', '魅族18', 'C++', 'C/C++', 'c++教程', 'bilibili旅行奇遇记', '飞机', '旅游', '生活', '出行', '情侣', '生活记录', '知识分享官', '校园学习', '国泰航空', '心理学', '人文', '社科·法律·心理', '男生', '是老师，也是UP主！', '英语', '要素过多', '哲学', '教育', '学习', '小姐姐', '模仿', '航空公司', '空姐', '春日迷影电影院', '美国电影', '电影解说', '影视', '影视杂谈', '电影', '空中浩劫', '历史', '国家地理', '空难', '空难调查', '纪录片', '日常', '舱内音乐', '机械', '混剪', '暑期爆肝挑战', '傲慢', '一起做手工吧！', '手工', '制作', '创意', '技术宅', '电路', '寻找2233位手工大神', '旧光驱改造', '原创', '手工制作', '做一种很新的手工', '美妆', '硬核', '自制', '手工绘画达人秀', '滴胶', '制作教程', '装机', '显卡', '搞笑研究所', '是在下输了', '万恶之源', '高能', '配音', '奇葩', '娱乐', '段子', '名场面', '娱乐杂谈', '爆笑', '谭谈交通', '同人配音', '影视剪辑', '剪辑', '高启盛', '高启强', 'PR教程', '野生技能协会', '视频剪辑', '熊大', '国产动画', '伴我雄芯', '熊出没', '熊二', '熊妈', '童年回忆杀', '童年', '动漫', '动画', '童年回忆', '非自然死亡', '人类迷惑行为', '逗比', '魔性', '歪果仁', '校园', '视频', '生物', '热点观察局', '美国', '星海计划', '社会', '财经商业', '趣闻', '揭秘', '餐饮', '科技和狠活', '社会洞察计划', '冷知识', '高考', '科学很可爱', '正经的知识又增加了', '必装软件', '实用软件', '软件推荐', '黑科技软件', '智能', '无人机', '电脑', '航拍', '纪实', '星海', '短片', '警察', '罪案', '刑侦', '破案', '插画', '绘画', '机器人', '有趣', '资讯', '环球', '高科技', '野生技术协会', 'AR到底多好玩', 'Air 1S XR', 'Meta Oculus Quest2', '战斗机', '空军', '航天', '计算机', '编程', '程序员', '模型', '手办模玩怎么玩？', '手办模玩', '手办·模玩', '高达模型', '万代', 'C语言', '编程入门', '零基础编程', '平板电脑', '编程语言', '这就是中国制造', '粉碎机', '解压', '中国', '金一南', 'AWE2023来啦', '华为', 'CPU', '电脑配置', 'ChatGPT', '文心一言', '通义千问', '宇宙', '天文', '太空', '社会观察局', '说说心理话', '美好生活日常记录', '盘点排行', 'UP！新学期', '职场', '心理', 'ChatGPT研究所', 'AI', '动画短片', '综合', '早教', '十万个为什么', '动画短片群星计划', '手书', '短片·手书·配音', '剧情', '健康', '天文学', '英语听力', '英语口语', '英语学习', '我们都爱搞学习', '三体', '专升本', '大学', '1分钟学个知识点', '汽车', '汽车生活', '军事科技', '军事科普', '解放军', '科普纪录', '案件', 'iPhone13', 'iPhone', '相机', '购物分享', '新的数码疆域等你探索！', '4K', '摄影', '手机评测', '开箱', '玩具', '手办', '忠告', '推荐', '开学季数码好物安利', '数码好物推荐', '科技数码', '定格动画', '科幻', '外星人', '原创动画', '一年一度好物大赛', '苹果', '打卡挑战', '手机平板', '惊悚', '自动驾驶', 'ChatGPT来啦', 'RPA之家', 'App推荐', '资源', '种草', '测评', '开眼界', '电影无名整活大赏', '动作', '鬼畜调教', '鬼畜', '鬼畜剧场', '星动安利大作战·春日篇', '618', '手机推荐', '安卓', '系统', 'OriginOS', '1024 程序员节，你有什么话想说？', '科技猎手计划·2022第四期', '小米', '我和数码的日常', '网络', '法制', '软件', '逻辑', '软件分享', '考试', '课程', '教学视频', '穿网线', '换网线', '公益', '伪常识', '动物观察局', '动物圈', '动物二创', '学习帮帮团', '原神UP主激励计划', 'GMV', '原神', '游戏', '手机游戏', '原神萌新', '命理', '玄学', '数学', '可莉', '证明', '历史人文档案馆', '人文历史', '历史人文档案馆2022第二季', '工业', '益智', '地理', '自然', 'vlog', '视频教程', '三农', 'Vlog', '励志', '记录我的春节碎片', '轨道交通', '可爱', '新年', '前方展望', '前面展望', 'POV', '电车', '交通工具', '新型', '改装玩车', '小剧场', 'bilibili新星计划', '记录出行的快乐', '苏州', '旅拍', '高明', '佛山', '有轨电车', '佛山地铁', '沙雕一夏，开心快乐每一天！', '地铁', '搞笑视频', '沙雕', '互联网', '灾难', '非洲', '昆虫', '人类', '大脑', '像素', '可视化', '测试', '正能量', '一天', '亲情', '日本', '外国', '生活这件小事', '俄罗斯', '国产', '一起fun放假', '你永远可以相信中国制造', '音乐', 'MV', '军事', '建设', 'MAD·AMV', '弦音-风舞高中弓道部', '二阶堂永亮', '京阿尼', '你这背景也太假了吧', '日本综艺', '综艺', '日本人', '新疆', '风景', '川建国', '老外', '爆米花机', '高铁', '教程', '国家宝藏', '影视混剪', '生命', '手绘', '抑郁症', '指尖上的二次元', '零基础', '新人', '黑历史', '火柴人动画', '万物皆可混剪', '战争', '舞蹈', '舞蹈综合', '社会摇', '影娱新春游园会', '开学', '元首', '夏日整活大赏', '进步', '神经网络', '考研', '公开课', '考研B看干货', '24考研', '24考研必买书单', '择校', '校园分享官', '麻省理工', '软件工程', '库克计算机基础', '信息技术', '计算机基础', '体验', 'OPPOReno10Pro', 'OPPO手机', '科技美学', '那岩', '微机分WekiHome', 'OPPO Reno10 系列', '反应', 'OPPO', 'OPPO Reno10 Pro', 'OPPO Reno10', '评测', '笔记本', '机箱', '硬核玩家制霸全场', '单机游戏', '冒险游戏', '地平线', '动作游戏', '互动视频', '游戏电脑', '装机方案', '组装电脑', '古墓丽影', '战神', '荒野大镖客', '刺客信条', '分镜', '马斯克', '机械设计', 'SOLIDWORKS', '非标设计', '设计教程', 'Solidworks', '“梗”之歌征集大赛', '音乐综合', '司墨尧smile', '华晨宇', '原创歌曲', '原创音乐', '职业职场', 'VLOG', '大学生特种兵', '春日旅行日记', '特种兵', '火车', '来唠唠你的五一假期', '五一', '大学生', '拿铁', '美食', '青春', '武汉', '热点', '压路机', '最新挖掘机视频', '大卡车运输挖土机', '挖机工作', '车辆用工程机械', '家庭', '机械原理', '制造', '设备', '挖掘机', '装备制造', '推土机', '亲子', '儿童', '工程车', '工程', 'YOUTUBE搬运', '摄影技巧', '片头', 'MG动画', '微电影', '下饭', 'PR', '设计·创意', '技能提升营', '蒙太奇', '后期', '主机游戏', '英雄联盟', ...

# %%
len(G)
# Out:
# 576

# %%
# 可视化
plt.figure(figsize=(15,14))
pos = nx.spring_layout(G, seed=5)
nx.draw(G, pos, with_labels=False)
plt.show()

# %% [markdown]
# ## 构建Node2Vec模型

# %%
from node2vec import Node2Vec

# %%
# 设置node2vec参数
node2vec = Node2Vec(G, 
                    dimensions=32,  # 嵌入维度
                    p=1,            # 回家参数
                    q=0.5,          # 外出参数
                    walk_length=5, # 随机游走最大长度
                    num_walks=100,  # 每个节点作为起始节点生成的随机游走个数
                    workers=4       # 并行线程数
                   )

# p=1, q=0.5, n_clusters=6。DFS深度优先搜索，挖掘同质社群
# p=1, q=2, n_clusters=3。BFS宽度优先搜索，挖掘节点的结构功能。

# 训练Node2Vec，参数文档见 gensim.models.Word2Vec
model = node2vec.fit(window=1,    # Skip-Gram窗口大小
                     min_count=1,  # 忽略出现次数低于此阈值的节点（词）
                     batch_words=4 # 每个线程处理的数据量
                    )
X = model.wv.vectors
# Out:
# Computing transition probabilities:   0%|          | 0/576 [00:00<?, ?it/s]

# %%
X.shape
# Out:
# (576, 32)

# %% [markdown]
# ## 节点Embedding聚类可视化

# %% [markdown]
# ### 运行聚类
#
# Kmeans聚类算法讲解：https://www.bilibili.com/video/BV1HJ411P7cs

# %%
# # DBSCAN聚类
# from sklearn.cluster import DBSCAN
# cluster_labels = DBSCAN(eps=0.5, min_samples=6).fit(X).labels_
# print(cluster_labels)

# KMeans聚类
from sklearn.cluster import KMeans
import numpy as np
cluster_labels = KMeans(n_clusters=3).fit(X).labels_
print(cluster_labels)
# Out:
# [0 1 1 2 0 2 2 2 0 2 2 1 2 1 2 0 0 0 0 1 2 1 1 0 1 0 0 0 1 0 2 1 1 2 0 2 1
#  0 1 1 1 1 0 1 2 2 0 1 0 1 2 1 1 2 1 0 0 2 1 0 2 2 2 0 1 0 1 1 0 1 1 1 2 2
#  2 0 1 2 2 2 1 2 2 2 2 1 2 2 1 2 0 2 2 0 2 1 1 1 2 1 0 1 1 0 1 1 2 1 0 1 0
#  2 2 1 0 1 1 1 0 2 0 1 2 1 2 2 1 1 1 0 0 0 1 2 2 0 2 0 2 1 0 2 0 1 0 1 2 1
#  1 2 2 1 2 1 2 1 2 1 0 2 0 0 0 0 1 1 2 0 0 2 1 2 1 0 0 2 1 1 2 1 2 2 2 2 1
#  0 1 0 1 2 0 0 1 1 1 2 0 0 1 2 1 1 2 1 0 2 1 1 2 1 0 0 1 1 1 2 0 2 2 0 1 2
#  1 1 1 1 0 2 2 2 0 0 1 1 0 2 0 2 0 2 0 1 0 0 1 2 1 0 0 0 1 1 2 0 0 1 0 2 2
#  1 1 1 1 1 0 1 2 1 1 2 0 0 0 2 1 1 1 1 2 1 0 0 1 1 2 2 2 1 0 2 2 1 2 1 1 0
#  1 0 2 1 0 2 1 1 0 1 2 2 1 2 1 2 0 1 0 2 0 2 0 1 1 1 2 2 1 2 2 0 0 0 2 2 0
#  1 2 1 1 2 2 2 1 1 2 1 2 2 2 0 2 2 1 1 1 1 1 2 2 1 2 0 2 2 0 1 2 0 1 1 2 2
#  1 2 2 2 2 2 2 2 2 2 2 0 1 1 1 2 0 2 2 0 1 2 2 2 1 1 0 0 2 1 2 2 2 2 2 2 2
#  1 2 0 0 2 0 2 1 2 1 2 0 2 0 2 2 2 2 2 1 0 0 2 1 2 0 2 0 2 0 2 0 0 0 1 2 1
#  0 2 2 0 0 0 2 0 0 0 0 2 2 1 2 0 0 2 0 2 2 1 1 2 0 2 2 0 1 0 1 1 2 2 2 2 2
#  1 2 1 1 2 2 2 0 1 2 1 0 2 0 1 1 1 0 2 0 1 0 0 0 1 2 2 1 1 0 0 2 2 0 0 1 2
#  0 1 0 2 0 0 0 1 1 0 0 2 0 2 0 1 2 0 2 0 2 0 2 0 2 0 1 0 0 0 0 1 2 1 0 1 1
#  0 1 1 0 2 1 0 0 0 0 1 1 0 2 0 1 1 1 1 1 1]

# %% [markdown]
# ### 将networkx中的节点和词向量中的节点对应
#
# 将词汇表的节点顺序转为networkx中的节点顺序

# %%
colors = []
nodes = list(G.nodes)
for node in nodes: # 按 networkx 的顺序遍历每个节点
    idx = model.wv.key_to_index[str(node)] # 获取这个节点在 embedding 中的索引号
    colors.append(cluster_labels[idx]) # 获取这个节点的聚类结果

# %% [markdown]
# ### 可视化聚类效果

# %%
plt.figure(figsize=(15,14))
pos = nx.spring_layout(G, seed=10)
nx.draw(G, pos, node_color=colors, with_labels=True)
plt.show()

# %% [markdown]
# ## 查看Embedding

# %%
model.wv.get_vector('手机').shape
# Out:
# (32,)

# %%
# 查看某个节点的Embedding
model.wv.get_vector('手机')
# Out:
# array([-0.6123239 , -0.32171738,  0.19469985,  0.7090762 , -0.12005675,
#        -0.5560054 ,  1.4027293 , -0.7866325 ,  0.09097326,  1.093967  ,
#         0.8475208 ,  0.08093984,  0.37951738, -0.37079018, -0.58250815,
#        -0.05660002, -0.9456736 ,  0.41112688,  0.6668082 ,  0.40042737,
#         1.7633615 ,  0.9040819 ,  1.5274686 , -0.21453838, -0.381715  ,
#        -0.9371682 , -0.12319962,  1.3539044 ,  1.5050322 , -0.44995272,
#        -0.18572466,  0.09886974], dtype=float32)

# %%
# 查找节点的相似节点
model.wv.most_similar('DIY')
# Out:
# [('滴胶', 0.80239337682724),
#  ('硬核', 0.7972599267959595),
#  ('制作教程', 0.7917220592498779),
#  ('电路', 0.7836117148399353),
#  ('旧光驱改造', 0.7743005752563477),
#  ('制作', 0.7724756002426147),
#  ('创意', 0.7119041681289673),
#  ('一起做手工吧！', 0.6878587007522583),
#  ('显卡', 0.6869184374809265),
#  ('折纸', 0.6799620985984802)]

# %%
# 查看任意两个节点的相似度
model.wv.similarity('玩具', '推荐')
# Out:
# 0.882445

# %%
# 查看任意两个节点的相似度DIY
model.wv.similarity('DIY', '旅游')
# Out:
# 0.14077583

# %% [markdown]
# ## 对Edge（连接）做Embedding

# %%
from node2vec.edges import HadamardEmbedder

# %%
# Hadamard 二元操作符：两个 Embedding 对应元素相乘
edges_embs = HadamardEmbedder(keyed_vectors=model.wv)

# %%
# 查看 任意两个节点连接 的 Embedding
edges_embs[('手机', '旅游')]
# Out:
# array([-1.93281740e-01,  3.25630277e-01, -3.24986577e-02, -3.38622212e-01,
#         1.16736069e-01,  5.04680336e-01,  9.69395101e-01,  1.35207188e+00,
#        -1.22155398e-01, -5.71472406e-01, -1.16194630e+00, -7.43030906e-02,
#         2.15778738e-01, -1.76117018e-01, -2.30797857e-01,  1.05999419e-02,
#        -5.75433136e-04, -7.03418255e-02, -1.80005312e-01,  2.12255836e-01,
#         1.29941225e+00,  9.80624974e-01,  1.84078300e+00,  2.12326273e-02,
#        -1.01043165e-01, -4.92344856e-01, -4.43624258e-02, -6.44728899e-01,
#        -2.72685010e-02,  5.86604059e-01,  1.73459306e-01,  3.77222104e-03],
#       dtype=float32)

# %%
# 计算所有 Edge 的 Embedding
edges_kv = edges_embs.as_keyed_vectors()
# Out:
# Generating edge features: 100%|██████████████████████████████████████████| 166176/166176.0 [00:00<00:00, 175694.00it/s]

# %%
edges_kv.index_to_key
# Out:
# ["('科技', '科技')",
#  "('中国制造', '科技')",
#  "('知识', '科技')",
#  "('搞笑', '科技')",
#  "('科技', '科技猎手2023')",
#  "('智轨电车', '科技')",
#  "('必剪创作', '科技')",
#  "('旅游', '科技')",
#  "('数码', '科技')",
#  "('生活', '科技')",
#  "('科技', '航空')",
#  "('科技', '科普')",
#  "('科技', '转场')",
#  "('工程机械', '科技')",
#  "('特种兵式旅游', '科技')",
#  "('科技', '黑科技')",
#  "('科技', '计算机技术')",
#  "('手机', '科技')",
#  "('opporeno10', '科技')",
#  "('科学科普', '科技')",
#  "('bilibili旅行奇遇记', '科技')",
#  "('科技', '飞机')",
#  "('万物研究所·第十期', '科技')",
#  "('DIY', '科技')",
#  "('科工机械', '科技')",
#  "('科技', '软件应用')",
#  "('电脑配置', '科技')",
#  "('极客DIY', '科技')",
#  "('动画', '科技')",
#  "('CPU', '科技')",
#  "('日常', '科技')",
#  "('科技', '纪实')",
#  "('科学', '科技')",
#  "('搞笑研究所', '科技')",
#  "('科技', '科技猎手')",
#  "('影视', '科技')",
#  "('机械', '科技')",
#  "('科技', '魅族18')",
#  "('你永远可以相信中国制造', '科技')",
#  "('星计划', '科技')",
#  "('校园学习', '科技')",
#  "('科技', '考研')",
#  "('动画短片群星计划', '科技')",
#  "('科技', '这就是中国制造')",
#  "('熊大', '科技')",
#  "('手工', '科技')",
#  "('人工智能', '科技')",
#  "('历史', '科技')",
#  "('短片', '科技')",
#  "('动画短片', '科技')",
#  "('Felix', '科技')",
#  "('知识分享官', '科技')",
#  "('原创', '科技')",
#  "('影视剪辑', '科技')",
#  "('冷知识', '科技')",
#  "('科技', '野生技术协会')",
#  "('硬核玩家制霸全场', '科技')",
#  "('星海计划', '科技')",
#  "('游戏', '科技')",
#  "('模型', '科技')",
#  "('科技', '空中浩劫')",
#  "('“梗”之歌征集大赛', '科技')",
#  "('科技', '美好生活日常记录')",
#  "('电影无名整活大赏', '科技')",
#  "('坦克世界', '科技')",
#  "('技术宅', '科技')",
#  "('热点观察局', '科技')",
#  "('科技', '计算机')",
#  "('科技', '编程')",
#  "('社会观察局', '科技')",
#  "('社科·法律·心理', '科技')",
#  "('机器人', '科技')",
#  "('出行', '科技')",
#  "('2023的第一场旅行', '科技')",
#  "('科技', '空军')",
#  "('手办模玩', '科技')",
#  "('GMV', '科技')",
#  "('科技', '记录我的春节碎片')",
#  "('科技', '航拍')",
#  "('影视混剪', '科技')",
#  "('原神UP主激励计划', '科技')",
#  "('PR教程', '科技')",
#  "('生活记录', '科技')",
#  "('旅拍', '科技')",
#  "('出门的快乐谁懂！', '科技')",
#  "('学习', '科技')",
#  "('手绘', '科技')",
#  "('沙雕一夏，开心快乐每一天！', '科技')",
#  "('军事科技', '科技')",
#  "('歪果仁', '科技')",
#  "('AR到底多好玩', '科技')",
#  "('摄影', '科技')",
#  "('科技', '跟着UP主出行看世界')",
#  "('短片·手书·配音', '科技')",
#  "('春日旅行日记', '科技')",
#  "('科学很可爱', '科技')",
#  "('是老师，也是UP主！', '科技')",
#  "('生物', '科技')",
#  "('中国', '科技')",
#  "('人文', '科技')",
#  "('电脑', '科技')",
#  "('你这背景也太假了吧', '科技')",
#  "('宇宙', '科技')",
#  "('科技', '装机')",
#  "('科技', '美国')",
#  "('万物研究所', '科技')",
#  "('生活这件小事', '科技')",
#  "('历史人文档案馆', '科技')",
#  "('显卡', '科技')",
#  "('科技', '野生技能协会')",
#  "('ChatGPT来啦', '科技')",
#  "('一起做手工吧！', '科技')",
#  "('科技', '记录出行的快乐')",
#  "('天文', '科技')",
#  "('OPPO Reno10', '科技')",
#  "('ChatGPT研究所', '科技')",
#  "('科技', '软件分享')",
#  "('科技', '资讯')",
#  "('手机评测', '科技')",
#  "('夏日整活大赏', '科技')",
#  "('相机', '科技')",
#  "('教育', '科技')",
#  "('寻找2233位手工大神', '科技')",
#  "('我们都爱搞学习', '科技')",
#  "('我是旅游课代表', '科技')",
#  "('科技', '音乐')",
#  "('社会洞察计划', '科技')",
#  "('科技', '英语听力')",
#  "('技能提升营', '科技')",
#  "('单机游戏', '科技')",
#  "('1024 程序员节，你有什么话想说？', '科技')",
#  "('平板电脑', '科技')",
#  "('战斗机', '科技')",
#  "('万物皆可混剪', '科技')",
#  "('小剧场', '科技')",
#  "('科技', '绘画')",
#  "('娱乐', '科技')",
#  "('开箱', '科技')",
#  "('社会', '科技')",
#  "('学习帮帮团', '科技')",
#  "('AWE2023来啦', '科技')",
#  "('做一种很新的手工', '科技')",
#  "('一年一度好物大赛', '科技')",
#  "('2022珠海航展有哪些亮点？', '科技')",
#  "('科技', '童年回忆杀')",
#  "('军事', '科技')",
#  "('剪辑', '科技')",
#  "('不止飞行', '科技')",
#  "('大学', '科技')",
#  "('折纸', '科技')",
#  "('科技', '鬼畜')",
#  "('人文历史', '科技')",
#  "('校园', '科技')",
#  "('科技', '综合')",
#  "('vlog', '科技')",
#  "('测试', '科技')",
#  "('国产动画', '科技')",
#  "('科技', '英语')",
#  "('无人机', '科技')",
#  "('科技', '风景')",
#  "('iPhone', '科技')",
#  "('安卓', '科技')",
#  "('科技', '考试')",
#  "('教学视频', '科技')",
#  "('科技', '航天')",
#  "('热点', '科技')",
#  "('国家地理', '科技')",
#  "('科技', '自制')",
#  "('开学季数码好物安利', '科技')",
#  "('科技', '高能')",
#  "('科技', '趣闻')",
#  "('人类迷惑行为', '科技')",
#  "('科技', '财经商业')",
#  "('原创动画', '科技')",
#  "('华为', '科技')",
#  "('科技', '视频剪辑')",
#  "('科技', '高考')",
#  "('科技', '视频教程')",
#  "('混剪', '科技')",
#  "('星海', '科技')",
#  "('科技', '音乐综合')",
#  "('1分钟学个知识点', '科技')",
#  "('影视杂谈', '科技')",
#  "('是在下输了', '科技')",
#  "('来唠唠你的五一假期', '科技')",
#  "('实用软件', '科技')",
#  "('科技', '网络游戏')",
#  "('体验', '科技')",
#  "('日本', '科技')",
#  "('正能量', '科技')",
#  "('手办模玩怎么玩？', '科技')",
#  "('手办·模玩', '科技')",
#  "('AI', '科技')",
#  "('工业', '科技')",
#  "('心理学', '科技')",
#  "('旅行', '科技')",
#  "('科技', '程序员')",
#  "('创意', '科技')",
#  "('制造', '科技')",
#  "('模仿', '科技')",
#  "('原神', '科技')",
#  "('星动安利大作战·春日篇', '科技')",
#  "('科技', '美食')",
#  "('刑侦', '科技')",
#  "('专升本', '科技')",
#  "('新疆', '科技')",
#  "('俄罗斯', '科技')",
#  "('环球', '科技')",
#  "('科技', '纪录片')",
#  "('教程', '科技')",
#  "('科技', '解压')",
#  "('ChatGPT', '科技')",
#  "('破案', '科技')",
#  "('科技', '罪案')",
#  "('京阿尼', '科技')",
#  "('万恶之源', '科技')",
#  "('科技', '粉碎机')",
#  "('战争', '科技')",
#  "('娱乐杂谈', '科技')",
#  "('手书', '科技')",
#  "('法制', '科技')",
#  "('李旻浩', '科技')",
#  "('二阶堂永亮', '科技')",
#  "('弦音-风舞高中弓道部', '科技')",
#  "('案件', '科技')",
#  "('MAD·AMV', '科技')",
#  "('科幻', '科技')",
#  "('PR', '科技')",
#  "('治愈', '科技')",
#  "('科技', '视频')",
#  "('汽车', '科技')",
#  "('测评', '科技')",
#  "('人类', '科技')",
#  "('互联网', '科技')",
#  "('Air 1S XR', '科技')",
#  "('科技', '空难调查')",
#  "('种草', '科技')",
#  "('电影', '科技')",
#  "('C语言', '科技')",
#  "('Stray Kids', '科技')",
#  "('推荐', '科技')",
#  "('科技', '警察')",
#  "('科技', '魅族')",
#  "('科技', '苹果')",
#  "('崩坏：星穹铁道创作者激励计划', '科技')",
#  "('科技', '空难')",
#  "('24考研必买书单', '科技')",
#  "('科技', '软件推荐')",
#  "('冒险游戏', '科技')",
#  "('科技', '系统')",
#  "('科技', '英语口语')",
#  "('科技', '鬼畜剧场')",
#  "('原创歌曲', '科技')",
#  "('制作', '科技')",
#  "('必装软件', '科技')",
#  "('公开课', '科技')",
#  "('科技', '网络')",
#  "('科技', '骑行')",
#  "('徐彰彬', '科技')",
#  "('万物皆可游戏', '科技')",
#  "('军武', '科技')",
#  "('科技', '鬼畜调教')",
#  "('健康', '科技')",
#  "('择校', '科技')",
#  "('反应', '科技')",
#  "('科学史', '科技')",
#  "('原创音乐', '科技')",
#  "('地理', '科技')",
#  "('男生', '科技')",
#  "('动漫', '科技')",
#  "('科技', '黑科技软件')",
#  "('动作游戏', '科技')",
#  "('地平线', '科技')",
#  "('搞笑视频', '科技')",
#  "('有趣', '科技')",
#  "('科技', '镜流')",
#  "('数学', '科技')",
#  "('亲子', '科技')",
#  "('伦敦', '科技')",
#  "('挖机工作', '科技')",
#  "('微机分WekiHome', '科技')",
#  "('科技', '那岩')",
#  "('科技', '英语学习')",
#  "('暗猫', '科技')",
#  "('科技', '童年')",
#  "('科技', '童年回忆')",
#  "('交通工具', '科技')",
#  "('YOUTUBE搬运', '科技')",
#  "('插画', '科技')",
#  "('华晨宇', '科技')",
#  "('bilibili打卡中国', '科技')",
#  "('万代', '科技')",
#  "('沙雕', '科技')",
#  "('24考研', '科技')",
#  "('原神萌新', '科技')",
#  "('Meta Oculus Quest2', '科技')",
#  "('爆米花机', '科技')",
#  "('OPPO Reno10 系列', '科技')",
#  "('科技', '苏州')",
#  "('电子竞技', '科技')",
#  "('OPPO', '科技')",
#  "('前方展望', '科技')",
#  "('崩坏：星穹铁道', '科技')",
#  "('最新挖掘机视频', '科技')",
#  "('OPPO手机', '科技')",
#  "('机械原理', '科技')",
#  "('电车', '科技')",
#  "('科技', '英国')",
#  "('科技', '英雄联盟')",
#  "('有轨电车', '科技')",
#  "('手机游戏', '科技')",
#  "('POV', '科技')",
#  "('OPPO Reno10 Pro', '科技')",
#  "('推土机', '科技')",
#  "('科技', '高达模型')",
#  "('科技', '美妆')",
#  "('OPPOReno10Pro', '科技')",
#  "('可爱', '科技')",
#  "('科技', '评测')",
#  "('科技', '车辆用工程机械')",
#  "('挖掘机', '科技')",
#  "('工程', '科技')",
#  "('中世纪', '科技')",
#  "('小众宝藏', '科技')",
#  "('科技', '考研B看干货')",
#  "('大理', '科技')",
#  "('科技', '轨道交通')",
#  "('战神', '科技')",
#  "('外星人', '科技')",
#  "('App推荐', '科技')",
#  "('北京', '科技')",
#  "('Vlog', '科技')",
#  "('科技', '科技美学')",
#  "('工程车', '科技')",
#  "('手工制作', '科技')",
#  "('天文学', '科技')",
#  "('历史人文档案馆2022第二季', '科技')",
#  "('改装玩车', '科技')",
#  "('佛山地铁', '科技')",
#  "('三农', '科技')",
#  "('科技', '装备制造')",
#  "('科技', '解放军')",
#  "('前面展望', '科技')",
#  "('儿童', '科技')",
#  "('攻略', '科技')",
#  "('云南', '科技')",
#  "('科技', '零基础')",
#  "('手办', '科技')",
#  "('新年', '科技')",
#  "('干货', '科技')",
#  "('压路机', '科技')",
#  "('坦克', '科技')",
#  "('科技', '科普纪录')",
#  "('智能制造  中国制造2025', '科技')",
#  "('中国力量', '科技')",
#  "('法国', '科技')",
#  "('段子', '科技')",
#  "('日本人', '科技')",
#  "('伴我雄芯', '科技')",
#  "('游戏电脑', '科技')",
#  "('科技', '警告')",
#  "('乘客', '科技')",
#  "('打卡挑战', '科技')",
#  "('像素', '科技')",
#  "('同人配音', '科技')",
#  "('科技', '荒野大镖客')",
#  "('科技', '金一南')",
#  "('外国人', '科技')",
#  "('科技', '运动')",
#  "('科技', '逗比')",
#  "('为汉科技', '科技')",
#  "('大学生', '科技')",
#  "('情侣', '科技')",
#  "('科技', '高启强')",
#  "('指尖上的二次元', '科技')",
#  "('科技', '穷游旅游')",
#  "('暑期爆肝挑战', '科技')",
#  "('熊妈', '科技')",
#  "('武汉', '科技')",
#  "('环球旅行', '科技')",
#  "('五一', '科技')",
#  "('科技', '编程入门')",
#  "('科技', '设备')",
#  "('建设', '科技')",
#  "('外国', '科技')",
#  "('盘点排行', '科技')",
#  "('信息技术', '科技')",
#  "('国泰航空', '科技')",
#  "('科技', '要素过多')",
#  "('科技', '科技猎手计划·2022第四期')",
#  "('动物圈', '科技')",
#  "('新型', '科技')",
#  "('地铁', '科技')",
#  "('UP！新学期', '科技')",
#  "('大卡车运输挖土机', '科技')",
#  "('后期', '科技')",
#  "('惊悚', '科技')",
#  "('互动视频', '科技')",
#  "('2023-bilibili出行达人征集令', '科技')",
#  "('公益', '科技')",
#  "('科技', '运动综合')",
#  "('科技', '音乐现场')",
#  "('佛山', '科技')",
#  "('农村', '科技')",
#  "('科技', '魔性')",
#  "('熊出没', '科技')",
#  "('火车', '科技')",
#  "('动物二创', '科技')",
#  "('科技', '黄铉辰')",
#  "('科技', '零基础编程')",
#  "('小米', '科技')",
#  "('科技', '震撼')",
#  "('OriginOS', '科技')",
#  "('电音', '科技')",
#  "('国产', '科技')",
#  "('vlog旅行记', '科技')",
#  "('一天', '科技')",
#  "('科技', '职业职场')",
#  "('RPA之家', '科技')",
#  "('科技', '配音')",
#  "('科技', '装机方案')",
#  "('拿铁', '科技')",
#  "('手工绘画达人秀', '科技')",
#  "('片头', '科技')",
#  "('摄影技巧', '科技')",
#  "('bilibili新星计划', '科技')",
#  "('川建国', '科技')",
#  "('微电影', '科技')",
#  "('机箱', '科技')",
#  "('特种兵', '科技')",
#  "('益智', '科技')",
#  "('科技', '舱内音乐')",
#  "('科技', '笔记本')",
#  "('大学生特种兵', '科技')",
#  "('科技', '科技数码')",
#  "('小姐姐', '科技')",
#  "('剧情', '科技')",
#  "('科技', '高明')",
#  "('拆解', '科技')",
#  "('定格动画', '科技')",
#  "('刺客信条', '科技')",
#  "('灾难', '科技')",
#  "('厦门航空', '科技')",
#  "('动物观察局', '科技')",
#  "('古墓丽影', '科技')",
#  "('春日迷影电影院', '科技')",
#  "('奇葩', '科技')",
#  "('C/C++', '科技')",
#  "('C++', '科技')",
#  "('4K', '科技')",
#  "('科技', '航空公司')",
#  "('科技', '穿网线')",
#  "('硬核', '科技')",
#  "('科技', '软件工程')",
#  "('科技', '购物分享')",
#  "('科技', '青春')",
#  "('bilibili出行奇遇记', '科技')",
#  "('十万个为什么', '科技')",
#  "('科技', '粉丝创作')",
#  "('科技', '软件')",
#  "('c++教程', '科技')",
#  "('VLOG', '科技')",
#  "('新的数码疆域等你探索！', '科技')",
#  "('MG动画', '科技')",
#  "('旅游攻略', '科技')",
#  "('科技', '高铁')",
#  "('科技', '非标设计')",
#  "('名场面', '科技')",
#  "('科技', '自动驾驶')",
#  "('新人', '科技')",
#  "('科技', '高启盛')",
#  "('科技', '魅族20')",
#  "('机械设计', '科技')",
#  "('科技', '进步')",
#  "('科技', '老外')",
#  "('日本综艺', '科技')",
#  "('熊二', '科技')",
#  "('当你把一件事做到极致', '科技')",
#  "('开学', '科技')",
#  "('一起fun放假', '科技')",
#  "('科技', '非自然死亡')",
#  "('哲学', '科技')",
#  "('司墨尧smile', '科技')",
#  "('大脑', '科技')",
#  "('Solidworks', '科技')",
#  "('爆笑', '科技')",
#  "('科技', '谭谈交通')",
#  "('科技', '空姐')",
#  "('科技', '课程')",
#  "('太空', '科技')",
#  "('主机游戏', '科技')",
#  "('科技', '高科技')",
#  "('科技', '餐饮')",
#  "('科技', '舞蹈')",
#  "('库克计算机基础', '科技')",
#  "('科技', '综艺')",
#  "('昆虫', '科技')",
#  "('MV', '科技')",
#  "('科技', '组装电脑')",
#  "('傲慢', '科技')",
#  "('数码好物推荐', '科技')",
#  "('4k', '科技')",
#  "('手机平板', '科技')",
#  "('科技', '通义千问')",
#  "('我和数码的日常', '科技')",
#  "('科技', '说说心理话')",
#  "('社会摇', '科技')",
#  "('影娱新春游园会', '科技')",
#  "('科技', '记忆力')",
#  "('科技', '非洲')",
#  "('分镜', '科技')",
#  "('下饭', '科技')",
#  "('火柴人动画', '科技')",
#  "('科技', '黑历史')",
#  "('智能', '科技')",
#  "('618', '科技')",
#  "('SOLIDWORKS', '科技')",
#  "('电影解说', '科技')",
#  "('忠告', '科技')",
#  "('心理', '科技')",
#  "('手机推荐', '科技')",
#  "('科技', '美国电影')",
#  "('小米手机', '科技')",
#  "('iPhone13', '科技')",
#  "('科技', '麻省理工')",
#  "('科技', '设计教程')",
#  "('家庭', '科技')",
#  "('科技', '资源')",
#  "('科技', '计算机基础')",
#  "('亲情', '科技')",
#  "('旧光驱改造', '科技')",
#  "('科技', '蒙太奇')",
#  "('换网线', '科技')",
#  "('科技', '设计·创意')",
#  "('生命', '科技')",
#  "('玩具', '科技')",
#  "('元首', '科技')",
#  "('动作', '科技')",
#  "('抑郁症', '科技')",
#  "('科技', '马斯克')",
#  "('科技', '舞蹈综合')",
#  "('揭秘', '科技')",
#  "('台词', '科技')",
#  "('制作教程', '科技')",
#  "('珠海航展', '科技')",
#  "('科技', '编程语言')",
#  "('校园分享官', '科技')",
#  "('人类史', '科技')",
#  "('电路', '科技')",
#  "('正经的知识又增加了', '科技')",
#  "('科技', '转角遇到春天')",
#  "('国家宝藏', '科技')",
#  "('科技', '科技和狠活')",
#  "('可视化', '科技')",
#  "('三体', '科技')",
#  "('SOTA', '科技')",
#  "('神经网络', '科技')",
#  "('玄学', '科技')",
#  "('滴胶', '科技')",
#  "('励志', '科技')",
#  "('早教', '科技')",
#  "('FOXP2', '科技')",
#  "('科技', '逻辑')",
#  "('汽车生活', '科技')",
#  "('文心一言', '科技')",
#  "('科技', '自然')",
#  "('科技', '装甲车')",
#  "('军事科普', '科技')",
#  "('电影剪辑', '科技')",
#  "('开眼界', '科技')",
#  "('伪常识', '科技')",
#  "('科技', '航模')",
#  "('科技', '职场')",
#  "('科技', '证明')",
#  "('可莉', '科技')",
#  "('命理', '科技')",
#  "('中国制造', '中国制造')",
#  "('中国制造', '知识')",
#  "('中国制造', '搞笑')",
#  "('中国制造', '科技猎手2023')",
#  "('中国制造', '智轨电车')",
#  "('中国制造', '必剪创作')",
#  "('中国制造', '旅游')",
#  "('中国制造', '数码')",
#  "('中国制造', '生活')",
#  "('中国制造', '航空')",
#  "('中国制造', '科普')",
#  "('中国制造', '转场')",
#  "('中国制造', '工程机械')",
#  "('中国制造', '特种兵式旅游')",
#  "('中国制造', '黑科技')",
#  "('中国制造', '计算机技术')",
#  "('中国制造', '手机')",
#  "('opporeno10', '中国制造')",
#  "('中国制造', '科学科普')",
#  "('bilibili旅行奇遇记', '中国制造')",
#  "('中国制造', '飞机')",
#  "('万物研究所·第十期', '中国制造')",
#  "('DIY', '中国制造')",
#  "('中国制造', '科工机械')",
#  "('中国制造', '软件应用')",
#  "('中国制造', '电脑配置')",
#  "('中国制造', '极客DIY')",
#  "('中国制造', '动画')",
#  "('CPU', '中国制造')",
#  "('中国制造', '日常')",
#  "('中国制造', '纪实')",
#  "('中国制造', '科学')",
#  "('中国制造', '搞笑研究所')",
#  "('中国制造', '科技猎手')",
#  "('中国制造', '影视')",
#  "('中国制造', '机械')",
#  "('中国制造', '魅族18')",
#  "('中国制造', '你永远可以相信中国制造')",
#  "('中国制造', '星计划')",
#  "('中国制造', '校园学习')",
#  "('中国制造', '考研')",
#  "('中国制造', '动画短片群星计划')",
#  "('中国制造', '这就是中国制造')",
#  "('中国制造', '熊大')",
#  "('中国制造', '手工')",
#  "('中国制造', '人工智能')",
#  "('中国制造', '历史')",
#  "('中国制造', '短片')",
#  "('中国制造', '动画短片')",
#  "('Felix', '中国制造')",
#  "('中国制造', '知识分享官')",
#  "('中国制造', '原创')",
#  "('中国制造', '影视剪辑')",
#  "('中国制造', '冷知识')",
#  "('中国制造', '野生技术协会')",
#  "('中国制造', '硬核玩家制霸全场')",
#  "('中国制造', '星海计划')",
#  "('中国制造', '游戏')",
#  "('中国制造', '模型')",
#  "('中国制造', '空中浩劫')",
#  "('“梗”之歌征集大赛', '中国制造')",
#  "('中国制造', '美好生活日常记录')",
#  "('中国制造', '电影无名整活大赏')",
#  "('中国制造', '坦克世界')",
#  "('中国制造', '技术宅')",
#  "('中国制造', '热点观察局')",
#  "('中国制造', '计算机')",
#  "('中国制造', '编程')",
#  "('中国制造', '社会观察局')",
#  "('中国制造', '社科·法律·心理')",
#  "('中国制造', '机器人')",
#  "('中国制造', '出行')",
#  "('2023的第一场旅行', '中国制造')",
#  "('中国制造', '空军')",
#  "('中国制造', '手办模玩')",
#  "('GMV', '中国制造')",
#  "('中国制造', '记录我的春节碎片')",
#  "('中国制造', '航拍')",
#  "('中国制造', '影视混剪')",
#  "('中国制造', '原神UP主激励计划')",
#  "('PR教程', '中国制造')",
#  "('中国制造', '生活记录')",
#  "('中国制造', '旅拍')",
#  "('中国制造', '出门的快乐谁懂！')",
#  "('中国制造', '学习')",
#  "('中国制造', '手绘')",
#  "('中国制造', '沙雕一夏，开心快乐每一天！')",
#  "('中国制造', '军事科技')",
#  "('中国制造', '歪果仁')",
#  "('AR到底多好玩', '中国制造')",
#  "('中国制造', '摄影')",
#  "('中国制造', '跟着UP主出行看世界')",
#  "('中国制造', '短片·手书·配音')",
#  "('中国制造', '春日旅行日记')",
#  "('中国制造', '科学很可爱')",
#  "('中国制造', '是老师，也是UP主！')",
#  "('中国制造', '生物')",
#  "('中国', '中国制造')",
#  "('中国制造', '人文')",
#  "('中国制造', '电脑')",
#  "('中国制造', '你这背景也太假了吧')",
#  "('中国制造', '宇宙')",
#  "('中国制造', '装机')",
#  "('中国制造', '美国')",
#  "('万物研究所', '中国制造')",
#  "('中国制造', '生活这件小事')",
#  "('中国制造', '历史人文档案馆')",
#  "('中国制造', '显卡')",
#  "('中国制造', '野生技能协会')",
#  "('ChatGPT来啦', '中国制造')",
#  "('一起做手工吧！', '中国制造')",
#  "('中国制造', '记录出行的快乐')",
#  "('中国制造', '天文')",
#  "('OPPO Reno10', '中国制造')",
#  "('ChatGPT研究所', '中国制造')",
#  "('中国制造', '软件分享')",
#  "('中国制造', '资讯')",
#  "('中国制造', '手机评测')",
#  "('中国制造', '夏日整活大赏')",
#  "('中国制造', '相机')",
#  "('中国制造', '教育')",
#  "('中国制造', '寻找2233位手工大神')",
#  "('中国制造', '我们都爱搞学习')",
#  "('中国制造', '我是旅游课代表')",
#  "('中国制造', '音乐')",
#  "('中国制造', '社会洞察计划')",
#  "('中国制造', '英语听力')",
#  "('中国制造', '技能提升营')",
#  "('中国制造', '单机游戏')",
#  "('1024 程序员节，你有什么话想说？', '中国制造')",
#  "('中国制造', '平板电脑')",
#  "('中国制造', '战斗机')",
#  "('万物皆可混剪', '中国制造')",
#  "('中国制造', '小剧场')",
#  "('中国制造', '绘画')",
#  "('中国制造', '娱乐')",
#  "('中国制造', '开箱')",
#  "('中国制造', '社会')",
#  "('中国制造', '学习帮帮团')",
#  "('AWE2023来啦', '中国制造')",
#  "('中国制造', '做一种很新的手工')",
#  "('一年一度好物大赛', '中国制造')",
#  "('2022珠海航展有哪些亮点？', '中国制造')",
#  "('中国制造', '童年回忆杀')",
#  "('中国制造', '军事')",
#  "('中国制造', '剪辑')",
#  "('不止飞行', '中国制造')",
#  "('中国制造', '大学')",
#  "('中国制造', '折纸')",
#  "('中国制造', '鬼畜')",
#  "('中国制造', '人文历史')",
#  "('中国制造', '校园')",
#  "('中国制造', '综合')",
#  "('vlog', '中国制造')",
#  "('中国制造', '测试')",
#  "('中国制造', '国产动画')",
#  "('中国制造', '英语')",
#  "('中国制造', '无人机')",
#  "('中国制造', '风景')",
#  "('iPhone', '中国制造')",
#  "('中国制造', '安卓')",
#  "('中国制造', '考试')",
#  "('中国制造', '教学视频')",
#  "('中国制造', '航天')",
#  "('中国制造', '热点')",
#  "('中国制造', '国家地理')",
#  "('中国制造', '自制')",
#  "('中国制造', '开学季数码好物安利')",
#  "('中国制造', '高能')",
#  "('中国制造', '趣闻')",
#  "('中国制造', '人类迷惑行为')",
#  "('中国制造', '财经商业')",
#  "('中国制造', '原创动画')",
#  "('中国制造', '华为')",
#  "('中国制造', '视频剪辑')",
#  "('中国制造', '高考')",
#  "('中国制造', '视频教程')",
#  "('中国制造', '混剪')",
#  "('中国制造', '星海')",
#  "('中国制造', '音乐综合')",
#  "('1分钟学个知识点', '中国制造')",
#  "('中国制造', '影视杂谈')",
#  "('中国制造', '是在下输了')",
#  "('中国制造', '来唠唠你的五一假期')",
#  "('中国制造', '实用软件')",
#  "('中国制造', '网络游戏')",
#  "('中国制造', '体验')",
#  "('中国制造', '日本')",
#  "('中国制造', '正能量')",
#  "('中国制造', '手办模玩怎么玩？')",
#  "('中国制造', '手办·模玩')",
#  "('AI', '中国制造')",
#  "('中国制造', '工业')",
#  "('中国制造', '心理学')",
#  "('中国制造', '旅行')",
#  "('中国制造', '程序员')",
#  "('中国制造', '创意')",
#  "('中国制造', '制造')",
#  "('中国制造', '模仿')",
#  "('中国制造', '原神')",
#  "('中国制造', '星动安利大作战·春日篇')",
#  "('中国制造', '美食')",
#  "('中国制造', '刑侦')",
#  "('专升本', '中国制造')",
#  "('中国制造', '新疆')",
#  "('中国制造', '俄罗斯')",
#  "('中国制造', '环球')",
#  "('中国制造', '纪录片')",
#  "('中国制造', '教程')",
#  "('中国制造', '解压')",
#  "('ChatGPT', '中国制造')",
#  "('中国制造', '破案')",
#  "('中国制造', '罪案')",
#  "('中国制造', '京阿尼')",
#  "('万恶之源', '中国制造')",
#  "('中国制造', '粉碎机')",
#  "('中国制造', '战争')",
#  "('中国制造', '娱乐杂谈')",
#  "('中国制造', '手书')",
#  "('中国制造', '法制')",
#  "('中国制造', '李旻浩')",
#  "('中国制造', '二阶堂永亮')",
#  "('中国制造', '弦音-风舞高中弓道部')",
#  "('中国制造', '案件')",
#  "('MAD·AMV', '中国制造')",
#  "('中国制造', '科幻')",
#  "('PR', '中国制造')",
#  "('中国制造', '治愈')",
#  "('中国制造', '视频')",
#  "('中国制造', '汽车')",
#  "('中国制造', '测评')",
#  "('中国制造', '人类')",
#  "('中国制造', '互联网')",
#  "('Air 1S XR', '中国制造')",
#  "('中国制造', '空难调查')",
#  "('中国制造', '种草')",
#  "('中国制造', '电影')",
#  "('C语言', '中国制造')",
#  "('Stray Kids', '中国制造')",
#  "('中国制造', '推荐')",
#  "('中国制造', '警察')",
#  "('中国制造', '魅族')",
#  "('中国制造', '苹果')",
#  "('中国制造', '崩坏：星穹铁道创作者激励计划')",
#  "('中国制造', '空难')",
#  "('24考研必买书单', '中国制造')",
#  "('中国制造', '软件推荐')",
#  "('中国制造', '冒险游戏')",
#  "('中国制造', '系统')",
#  "('中国制造', '英语口语')",
#  "('中国制造', '鬼畜剧场')",
#  "('中国制造', '原创歌曲')",
#  "('中国制造', '制作')",
#  "('中国制造', '必装软件')",
#  "('中国制造', '公开课')",
#  "('中国制造', '网络')",
#  "('中国制造', '骑行')",
#  "('中国制造', '徐彰彬')",
#  "('万物皆可游戏', '中国制造')",
#  "('中国制造', '军武')",
#  "('中国制造', '鬼畜调教')",
#  "('中国制造', '健康')",
#  "('中国制造', '择校')",
#  "('中国制造', '反应')",
#  "('中国制造', '科学史')",
#  "('中国制造', '原创音乐')",
#  "('中国制造', '地理')",
#  "('中国制造', '男生')",
#  "('中国制造', '动漫')",
#  "('中国制造', '黑科技软件')",
#  "('中国制造', '动作游戏')",
#  "('中国制造', '地平线')",
#  "('中国制造', '搞笑视频')",
#  "('中国制造', '有趣')",
#  "('中国制造', '镜流')",
#  "('中国制造', '数学')",
#  "('中国制造', '亲子')",
#  "('中国制造', '伦敦')",
#  "('中国制造', '挖机工作')",
#  "('中国制造', '微机分WekiHome')",
#  "('中国制造', '那岩')",
#  "('中国制造', '英语学习')",
#  "('中国制造', '暗猫')",
#  "('中国制造', '童年')",
#  "('中国制造', '童年回忆')",
#  "('中国制造', '交通工具')",
#  "('YOUTUBE搬运', '中国制造')",
#  "('中国制造', '插画')",
#  "('中国制造', '华晨宇')",
#  "('bilibili打卡中国', '中国制造')",
#  "('万代', '中国制造')",
#  "('中国制造', '沙雕')",
#  "('24考研', '中国制造')",
#  "('中国制造', '原神萌新')",
#  "('Meta Oculus Quest2', '中国制造')",
#  "('中国制造', '爆米花机')",
#  "('OPPO Reno10 系列', '中国制造')",
#  "('中国制造', '苏州')",
#  "('中国制造', '电子竞技')",
#  "('OPPO', '中国制造')",
#  "('中国制造', '前方展望')",
#  "('中国制造', '崩坏：星穹铁道')",
#  "('中国制造', '最新挖掘机视频')",
#  "('OPPO手机', '中国制造')",
#  "('中国制造', '机械原理')",
#  "('中国制造', '电车')",
#  "('中国制造', '英国')",
#  "('中国制造', '英雄联盟')",
#  "('中国制造', '有轨电车')",
#  "('中国制造', '手机游戏')",
#  "('POV', '中国制造')",
#  "('OPPO Reno10 Pro', '中国制造')",
#  "('中国制造', '推土机')",
#  "('中国制造', '高达模型')",
#  "('中国制造', '美妆')",
#  "('OPPOReno10Pro', '中国制造')",
#  "('中国制造', '可爱')",
#  "('中国制造', '评测')",
#  "('中国制造', '车辆用工程机械')",
#  "('中国制造', '挖掘机')",
#  "('中国制造', '工程')",
#  "('中世纪', '中国制造')",
#  "('中国制造', '小众宝藏')",
#  "('中国制造', '考研B看干货')",
#  "('中国制造', '大理')",
#  "('中国制造', '轨道交通')",
#  "('中国制造', '战神')",
#  "('中国制造', '外星人')",
#  "('App推荐', '中国制造')",
#  "('中国制造', '北京')",
#  "('Vlog', '中国制造')",
#  "('中国制造', '科技美学')",
#  "('中国制造', '工程车')",
#  "('中国制造', '手工制作')",
#  "('中国制造', '天文学')",
#  "('中国制造', '历史人文档案馆2022第二季')",
#  "('中国制造', '改装玩车')",
#  "('中国制造', '佛山地铁')",
#  "('三农', '中国制造')",
#  "('中国制造', '装备制造')",
#  "('中国制造', '解放军')",
#  "('中国制造', '前面展望')",
#  "('中国制造', '儿童')",
#  "('中国制造', '攻略')",
#  "('中国制造', '云南')",
#  "('中国制造', '零基础')",
#  "('中国制造', '手办')",
#  "('中国制造', '新年')",
#  "('中国制造', '干货')",
#  "('中国制造', '压路机')",
#  "('中国制造', '坦克')",
#  "('中国制造', '科普纪录')",
#  "('中国制造', '智能制造  中国制造2025')",
#  "('中国制造', '中国力量')",
#  "('中国制造', '法国')",
#  "('中国制造', '段子')",
#  "('中国制造', '日本人')",
#  "('中国制造', '伴我雄芯')",
#  "('中国制造', '游戏电脑')",
#  "('中国制造', '警告')",
#  "('中国制造', '乘客')",
#  "('中国制造', '打卡挑战')",
#  "('中国制造', '像素')",
#  "('中国制造', '同人配音')",
#  "('中国制造', '荒野大镖客')",
#  "('中国制造', '金一南')",
#  "('中国制造', '外国人')",
#  "('中国制造', '运动')",
#  "('中国制造', '逗比')",
#  "('中国制造', '为汉科技')",
#  "('中国制造', '大学生')",
#  "('中国制造', '情侣')",
#  "('中国制造', '高启强')",
#  "('中国制造', '指尖上的二次元')",
#  "('中国制造', '穷游旅游')",
#  "('中国制造', '暑期爆肝挑战')",
#  "('中国制造', '熊妈')",
#  "('中国制造', '武汉')",
#  "('中国制造', '环球旅行')",
#  "('中国制造', '五一')",
#  "('中国制造', '编程入门')",
#  "('中国制造', '设备')",
#  "('中国制造', '建设')",
#  "('中国制造', '外国')",
#  "('中国制造', '盘点排行')",
#  "('中国制造', '信息技术')",
#  "('中国制造', '国泰航空')",
#  "('中国制造', '要素过多')",
#  "('中国制造', '科技猎手计划·2022第四期')",
#  "('中国制造', '动物圈')",
#  "('中国制造', '新型')",
#  "('中国制造', '地铁')",
#  "('UP！新学期', '中国制造')",
#  "('中国制造', '大卡车运输挖土机')",
#  "('中国制造', '后期')",
#  "('中国制造', '惊悚')",
#  "('中国制造', '互动视频')",
#  "('2023-bilibili出行达人征集令', '中国制造')",
#  "('中国制造', '公益')",
#  "('中国制造', '运动综合')",
#  "('中国制造', '音乐现场')",
#  "('中国制造', '佛山')",
#  "('中国制造', '农村')",
#  "('中国制造', '魔性')",
#  "('中国制造', '熊出没')",
#  "('中国制造', '火车')",
#  "('中国制造', '动物二创')",
#  "('中国制造', '黄铉辰')",
#  "('中国制造', '零基础编程')",
#  "('中国制造', '小米')",
#  "('中国制造', '震撼')",
#  "('OriginOS', '中国制造')",
#  "('中国制造', '电音')",
#  "('中国制造', '国产')",
#  "('vlog旅行记', '中国制造')",
#  "('一天', '中国制造')",
#  "('中国制造', '职业职场')",
#  "('RPA之家', '中国制造')",
#  "('中国制造', '配音')",
#  "('中国制造', '装机方案')",
#  "('中国制造', '拿铁')",
#  "('中国制造', '手工绘画达人秀')",
#  "('中国制造', '片头')",
#  "('中国制造', '摄影技巧')",
#  ...]

# %%
# 查看 关系与 某两个节点 最相似的 节点对
edges_kv.most_similar(str(('手机', '旅游')))
# Out:
# [("('北京', '手机')", 0.8882913589477539),
#  ("('大理', '手机')", 0.8741518259048462),
#  ("('bilibili出行奇遇记', '手机')", 0.8683679103851318),
#  ("('手机', '旅游攻略')", 0.8654487729072571),
#  ("('手机', '运动综合')", 0.8612919449806213),
#  ("('干货', '手机')", 0.8585073947906494),
#  ("('2023-bilibili出行达人征集令', '手机')", 0.8576771020889282),
#  ("('手机', '运动')", 0.8572484254837036),
#  ("('OriginOS', '旅游')", 0.8540804982185364),
#  ("('手机', '穷游旅游')", 0.8505664467811584)]

# %% [markdown]
# ## PCA降维可视化

# %% [markdown]
# ### 可视化全部词条的二维Embedding¶

# %%
X = model.wv.vectors

# %%
# 将Embedding用PCA降维到2维
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
embed_2d = pca.fit_transform(X)

# %%
embed_2d.shape
# Out:
# (576, 2)

# %%
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:, 0], embed_2d[:, 1])
plt.show()

# %%
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:, 0], embed_2d[:, 1], c=colors, alpha=0.8)
plt.show()

# %% [markdown]
# ## TSNE降维可视化

# %% [markdown]
# ### 可视化全部词条的二维Embedding¶

# %%
# 将Embedding用TSNE降维到2维
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, n_iter=1000)
embed_2d = tsne.fit_transform(X)
# Out:
# D:\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# D:\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:, 0], embed_2d[:, 1])
plt.show()

# %%
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:, 0], embed_2d[:, 1], c=colors, alpha=0.8)
plt.show()

#可以看到TSNE降维可视化的效果更好一些

# %% [markdown]
# ### 可视化某个词条的二维Embedding

# %%
term = '手机'

# %%
term_256d = model.wv[term].reshape(1,-1)

# %%
term_256d.shape
# Out:
# (1, 32)

# %%
term_2d = pca.transform(term_256d)

# %%
term_2d
# Out:
# array([[-1.7841772, -1.2273397]], dtype=float32)

# %%
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:,0], embed_2d[:,1])
plt.scatter(term_2d[:,0],term_2d[:,1],c='r',s=200)
plt.show()

# %% [markdown]
# ### 可视化某些词条的二维Embedding

# %%
# 计算PageRank重要度
pagerank = nx.pagerank(G)
# 从高到低排序
node_importance = sorted(pagerank.items(), key=lambda x:x[1], reverse=True)

# %%
# 取最高的前n个节点
n = 50
terms_chosen = []
for each in node_importance[:n]:
    terms_chosen.append(each[0])

# %%
# 手动补充新节点
# terms_chosen.extend(['computer vision','deep learning','convolutional neural network','convolution','natural-language processing','attention (machine learning)','support-vector machine','decision tree','random forest','computational imaging','machine vision','cognitive science','neuroscience','psychophysics','brain','visual cortex','visual neuroscience','cognitive model','finite difference','finite difference time domain','finite difference coefficients','finite difference methods for option pricing','iso 128','iso 10303'])

# %%
terms_chosen
# Out:
# ['科技',
#  '知识',
#  '中国制造',
#  '科技猎手2023',
#  '搞笑',
#  '必剪创作',
#  '数码',
#  '科普',
#  '生活',
#  '转场',
#  '智轨电车',
#  '旅游',
#  '航空',
#  '特种兵式旅游',
#  '工程机械',
#  '黑科技',
#  '计算机技术',
#  '手机',
#  '科学科普',
#  '飞机',
#  'bilibili旅行奇遇记',
#  '万物研究所·第十期',
#  'opporeno10',
#  'DIY',
#  '科工机械',
#  '极客DIY',
#  '软件应用',
#  '电脑配置',
#  '动画',
#  'CPU',
#  '日常',
#  '科学',
#  '科技猎手',
#  '机械',
#  '纪实',
#  '影视',
#  '搞笑研究所',
#  '魅族18',
#  '校园学习',
#  '野生技术协会',
#  '历史',
#  '这就是中国制造',
#  '人工智能',
#  '影视剪辑',
#  '动画短片群星计划',
#  '知识分享官',
#  '短片',
#  '动画短片',
#  '手工',
#  '星计划']

# %% [markdown]
# ### 可视化全部词条和关键词条的二维Embedding

# %%
# 输入词条，输出词典中的索引号
term2index = model.wv.key_to_index

# %%
# index2term = model.wv.index_to_key
# term_index = np.array(term2index.values())

# %%
plt.figure(figsize=(14,14))
plt.scatter(embed_2d[:,0], embed_2d[:,1])

for item in terms_chosen:
    idx = term2index[item]
    plt.scatter(embed_2d[idx,0], embed_2d[idx,1],c='r',s=50)
    plt.annotate(item, xy=(embed_2d[idx,0], embed_2d[idx,1]),c='k',fontsize=12)
plt.show()

# %%
embed_2d.shape
# Out:
# (576, 2)

# %% [markdown]
# ### 导出TSNE降维到二维之后的Embedding

# %%
terms_chosen_mask = np.zeros(X.shape[0])
for item in terms_chosen:
    idx = term2index[item]
    terms_chosen_mask[idx] = 1

# %%
df = pd.DataFrame()
df['X'] = embed_2d[:,0]
df['Y'] = embed_2d[:,1]
df['item'] = model.wv.index_to_key
df['pagerank'] = pagerank.values()
df['chosen'] = terms_chosen_mask

# %%
df
# Out:
#              X          Y      item  pagerank  chosen
# 0     9.665904  -3.041082        科技  0.004904     1.0
# 1   -10.823073  18.707937      中国制造  0.017677     1.0
# 2     1.104603   7.677391        知识  0.013833     1.0
# 3    -1.621081 -13.497082        搞笑  0.008744     1.0
# 4    21.051409  -3.320163  科技猎手2023  0.017225     1.0
# ..         ...        ...       ...       ...     ...
# 571  -7.458965   1.973979        航模  0.000631     0.0
# 572   4.985901   3.026623        职场  0.000631     0.0
# 573   1.115490   6.731166        证明  0.000608     0.0
# 574   0.933523   6.863841        可莉  0.000608     0.0
# 575   0.926264   6.799287        命理  0.000608     0.0
#
# [576 rows x 5 columns]

# %%
df.to_csv('tsne_vis_2d.csv',index=False)
